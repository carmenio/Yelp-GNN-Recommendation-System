# %% [markdown]
# # hgn_recommendation

# %% [markdown]
# ## Heterogeneous Graph Construction

# %%
import pandas as pd
business_df = pd.read_parquet('../../Data/preprocessed_business.parquet', engine='pyarrow')
business_df.columns
# Out:
# Index(['business_id_index', 'business_id', 'name', 'address', 'city', 'state',
#        'postal_code', 'latitude', 'longitude', 'stars', 'review_count',
#        'is_open', 'attributes', 'categories', 'hours', 'category_list',
#        'category_index', 'categories-cleaned', 'name-cleaned',
#        'address-cleaned', 'category_embeddings', 'name_embeddings',
#        'address_embeddings'],
#       dtype='object')

# %%
import pandas as pd
import torch
import torch_geometric.transforms as T
import pickle
from torch_geometric.data import HeteroData
import numpy as np

review_df = pd.read_parquet('../../Data/preprocessed_review.parquet', engine='pyarrow')
user_df = pd.read_parquet('../../Data/preprocessed_user.parquet', engine='pyarrow')
business_df = pd.read_parquet('../../Data/preprocessed_business.parquet', engine='pyarrow')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

category_embeddings=torch.from_numpy(np.stack(business_df['category_embeddings'].values)).float()

# %%
import pandas as pd
import torch
import torch_geometric.transforms as T
import pickle
from torch_geometric.data import HeteroData
version='alll'

review_df = pd.read_parquet('../../Data/preprocessed_review.parquet', engine='pyarrow')
user_df = pd.read_parquet('../../Data/preprocessed_user.parquet', engine='pyarrow')
business_df = pd.read_parquet('../../Data/preprocessed_business.parquet', engine='pyarrow')

# loading business_category_index
with open('../../Data/business_category_index.pickle', 'rb') as handle:
    business_category_index = pickle.load(handle)

### Nodes ###
# User features
user_features=torch.from_numpy(user_df[['review_count', 'useful', 'funny', 'cool', 'fans', 'average_stars']].values).to(torch.float)  # [num_users, num_features_users]
print(user_features.shape)

# Business features
business_simple_features=torch.from_numpy(business_df[['stars', 'review_count', 'is_open', 'latitude', 'longitude']].values).to(torch.float)  # [num_businesses, num_features_businesses]
business_category_embeddings=torch.from_numpy(np.stack(business_df['category_embeddings'].values)).float()
business_name_embeddings=torch.from_numpy(np.stack(business_df['name_embeddings'].values)).float()
business_address_embeddings=torch.from_numpy(np.stack(business_df['address_embeddings'].values)).float()
business_features=torch.cat([business_simple_features,
                             business_category_embeddings,
                             business_name_embeddings,
                             business_address_embeddings,
                             ],
                             dim=1)

print(business_features.shape)

# Business Categories
# category_features = torch.eye(len(business_category_index))

### Edges ###
# Review edge index
review_edge_index=torch.stack([
    torch.tensor(review_df['user_id_index'].values),
    torch.tensor(review_df['business_id_index'].values)]
    , dim=0)
assert review_edge_index.shape == (2, len(review_df))
print('review_edge_index.shape:',review_edge_index.shape)

# Review edge label
rating=torch.from_numpy(review_df['stars'].values).to(torch.float)
print('rating.shape:',rating.shape)

# Friend edge index
user_friend_index = torch.tensor([
    (user, friend)                                      # 3) Tuple of users and friends
    for user, friend_list in user_df['friends'].items() # 1) Parent-loop, across each user in user_df
    for friend in friend_list                           # 2) Child-loop, across each friend of each user
], dtype=torch.long).t().contiguous()                   # 4) Convert to tensor and transpose to required shape
print('user_friend_index.shape:',user_friend_index.shape)

# Business category edge index
business_category_index = torch.tensor([
    (business, category)                                                 # 3) Tuple of businesses and their categories
    for business, category_list in business_df['category_index'].items() # 1) Parent-loop, across each business in business_df
    for category in category_list                                        # 2) Child-loop, across each category in category_list
], dtype=torch.long).t().contiguous()                                    # 4) Convert to tensor and transpose to required shape
print('business_category_index.shape:',business_category_index.shape)

data = HeteroData()
data['user'].x = user_features
data['business'].x = business_features
data['user','rates','business'].edge_index=review_edge_index
data['user','rates','business'].edge_label=rating
# data['user','friends','user'].edge_index=user_friend_index
# data['business','part_of','category'].edge_index=business_category_index

# Add the reverse edges in order to let a GNN be able to pass messages in both directions.
# We can leverage the `T.ToUndirected()` transform for this from PyG:
data = T.ToUndirected()(data)

# With the above transformation we also got reversed labels for the edges.
# We are going to remove them:
del data['business', 'rev_rates', 'user'].edge_label

# Save the HeteroData object
torch.save(data, f'../../Data/hetero_data-{version}.pt')

print(data)

del review_df, user_df, business_df, user_features, business_features, review_edge_index, rating
del user_friend_index, business_category_index, data
# Out:
# torch.Size([227407, 6])
# torch.Size([14576, 1157])
# review_edge_index.shape: torch.Size([2, 686422])
# rating.shape: torch.Size([686422])
# user_friend_index.shape: torch.Size([2, 1345962])
# business_category_index.shape: torch.Size([2, 63851])
# HeteroData(
#   user={ x=[227407, 6] },
#   business={ x=[14576, 1157] },
#   (user, rates, business)={
#     edge_index=[2, 686422],
#     edge_label=[686422],
#   },
#   (business, rev_rates, user)={ edge_index=[2, 686422] }
# )

# %% [markdown]
# ## Train-Test split

# %%
import torch
import torch_geometric.transforms as T
from torch_geometric.data import HeteroData
import random

# Set seeds for reproducibility
torch.manual_seed(42)
random.seed(42)

data = torch.load('../../Data/hetero_data.pt', weights_only=False)
train_data, val_data, test_data = T.RandomLinkSplit(
    num_val=0.1,
    num_test=0.1,
    neg_sampling_ratio=0.0,
    edge_types=[('user', 'rates', 'business')],
    rev_edge_types=[('business', 'rev_rates', 'user')],
)(data)
train_data, val_data
data
# Out:
# HeteroData(
#   user={ x=[227407, 6] },
#   business={ x=[14576, 5] },
#   (user, rates, business)={
#     edge_index=[2, 686422],
#     edge_label=[686422],
#   },
#   (business, rev_rates, user)={ edge_index=[2, 686422] }
# )

# %% [markdown]
# ## Graph Neural Network

# %%
from torch_geometric.nn import SAGEConv, to_hetero

class GNNEncoder(torch.nn.Module):
    def __init__(self, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = SAGEConv((-1, -1), hidden_channels)
        self.conv2 = SAGEConv((-1, -1), out_channels)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        x = self.conv2(x, edge_index)
        return x

class EdgeDecoder(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        self.lin1 = torch.nn.Linear(2 * hidden_channels, hidden_channels)
        self.lin2 = torch.nn.Linear(hidden_channels, 1)

    def forward(self, z_dict, edge_label_index):
        row, col = edge_label_index
        z = torch.cat([z_dict['user'][row], z_dict['business'][col]], dim=-1)

        z = self.lin1(z).relu()
        z = self.lin2(z)
        return z.view(-1)

class Model(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        self.encoder = GNNEncoder(hidden_channels, hidden_channels)
        self.encoder = to_hetero(self.encoder, data.metadata(), aggr='sum')
        self.decoder = EdgeDecoder(hidden_channels)

    def forward(self, x_dict, edge_index_dict, edge_label_index):
        z_dict = self.encoder(x_dict, edge_index_dict)
        return self.decoder(z_dict, edge_label_index)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = Model(hidden_channels=32).to(device)

print(model)
# Out:
# Model(
#   (encoder): GraphModule(
#     (conv1): ModuleDict(
#       (user__rates__business): SAGEConv((-1, -1), 32, aggr=mean)
#       (business__rev_rates__user): SAGEConv((-1, -1), 32, aggr=mean)
#     )
#     (conv2): ModuleDict(
#       (user__rates__business): SAGEConv((-1, -1), 32, aggr=mean)
#       (business__rev_rates__user): SAGEConv((-1, -1), 32, aggr=mean)
#     )
#   )
#   (decoder): EdgeDecoder(
#     (lin1): Linear(in_features=64, out_features=32, bias=True)
#     (lin2): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
writer = SummaryWriter()

def train():
    model.train()
    optimizer.zero_grad()
    pred = model(train_data.x_dict, 
                 train_data.edge_index_dict,
                 train_data['user', 'rates', 'business'].edge_label_index
                 )
    target = train_data['user', 'rates', 'business'].edge_label
    loss = F.mse_loss(pred, target)
    loss.backward()
    optimizer.step()
    return float(loss)

@torch.no_grad()
def test(data):
    data = data.to(device)
    model.eval()
    pred = model(data.x_dict,
                 data.edge_index_dict,
                 data['user','rates', 'business'].edge_label_index
                 )
    pred = pred.clamp(min=0, max=5)
    target = data['user', 'rates', 'business'].edge_label.float()
    rmse = F.mse_loss(pred, target).sqrt()
    return float(rmse)

best_val = float('inf')
for epoch in range(1, 3001):
    train_data = train_data.to(device)
    loss = train()
    train_rmse = test(train_data)
    val_rmse = test(val_data)

    writer.add_scalar("Loss", loss, epoch)
    writer.add_scalar("Train rmse", train_rmse, epoch)
    writer.add_scalar("Val rsme", val_rmse, epoch)

    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train: {train_rmse:.4f}, '
          f'Val: {val_rmse:.4f}')

    if val_rmse < best_val:
        best_val = val_rmse
        best_state = model.state_dict()
        patience = 0
    else:
        patience += 1
        if patience >= 1000:
            print("Early stopping.")
            break

writer.close()
model.load_state_dict(best_state)
torch.save(model.state_dict(), f"../Saved_Models/hgn_model-{version}.pt")
# Out:
# Epoch: 001, Loss: 1.0996, Train: 0.7780, Val: 0.7771
# Epoch: 002, Loss: 0.7348, Train: 0.6801, Val: 0.6974
# Epoch: 003, Loss: 0.4626, Train: 0.5201, Val: 0.5591
# Epoch: 004, Loss: 0.2705, Train: 0.4209, Val: 0.4601
# Epoch: 005, Loss: 0.1772, Train: 0.3707, Val: 0.4023
# Epoch: 006, Loss: 0.1376, Train: 0.3596, Val: 0.3805
# Epoch: 007, Loss: 0.1296, Train: 0.3790, Val: 0.3873
# Epoch: 008, Loss: 0.1439, Train: 0.4013, Val: 0.4009
# Epoch: 009, Loss: 0.1612, Train: 0.4087, Val: 0.4057
# Epoch: 010, Loss: 0.1672, Train: 0.3995, Val: 0.3992
# Epoch: 011, Loss: 0.1597, Train: 0.3811, Val: 0.3872
# Epoch: 012, Loss: 0.1452, Train: 0.3627, Val: 0.3774
# Epoch: 013, Loss: 0.1316, Train: 0.3520, Val: 0.3761
# Epoch: 014, Loss: 0.1241, Train: 0.3556, Val: 0.3870
# Epoch: 015, Loss: 0.1269, Train: 0.3677, Val: 0.4023
# Epoch: 016, Loss: 0.1360, Train: 0.3688, Val: 0.4059
# Epoch: 017, Loss: 0.1369, Train: 0.3628, Val: 0.4012
# Epoch: 018, Loss: 0.1325, Train: 0.3566, Val: 0.3943
# Epoch: 019, Loss: 0.1280, Train: 0.3511, Val: 0.3874
# Epoch: 020, Loss: 0.1241, Train: 0.3485, Val: 0.3825
# Epoch: 021, Loss: 0.1221, Train: 0.3485, Val: 0.3801
# Epoch: 022, Loss: 0.1220, Train: 0.3500, Val: 0.3794
# Epoch: 023, Loss: 0.1229, Train: 0.3513, Val: 0.3794
# Epoch: 024, Loss: 0.1237, Train: 0.3514, Val: 0.3795
# Epoch: 025, Loss: 0.1238, Train: 0.3503, Val: 0.3796
# Epoch: 026, Loss: 0.1229, Train: 0.3481, Val: 0.3802
# Epoch: 027, Loss: 0.1213, Train: 0.3475, Val: 0.3839
# Epoch: 028, Loss: 0.1208, Train: 0.3480, Val: 0.3880
# Epoch: 029, Loss: 0.1211, Train: 0.3474, Val: 0.3890
# Epoch: 030, Loss: 0.1207, Train: 0.3456, Val: 0.3865
# Epoch: 031, Loss: 0.1195, Train: 0.3440, Val: 0.3834
# Epoch: 032, Loss: 0.1184, Train: 0.3434, Val: 0.3818
# Epoch: 033, Loss: 0.1179, Train: 0.3432, Val: 0.3814
# Epoch: 034, Loss: 0.1178, Train: 0.3426, Val: 0.3816
# Epoch: 035, Loss: 0.1174, Train: 0.3419, Val: 0.3824
# Epoch: 036, Loss: 0.1169, Train: 0.3413, Val: 0.3836
# Epoch: 037, Loss: 0.1165, Train: 0.3410, Val: 0.3847
# Epoch: 038, Loss: 0.1163, Train: 0.3407, Val: 0.3853
# Epoch: 039, Loss: 0.1160, Train: 0.3401, Val: 0.3850
# Epoch: 040, Loss: 0.1157, Train: 0.3394, Val: 0.3839
# Epoch: 041, Loss: 0.1152, Train: 0.3389, Val: 0.3825
# Epoch: 042, Loss: 0.1148, Train: 0.3384, Val: 0.3814
# Epoch: 043, Loss: 0.1145, Train: 0.3380, Val: 0.3807
# Epoch: 044, Loss: 0.1142, Train: 0.3373, Val: 0.3805
# Epoch: 045, Loss: 0.1138, Train: 0.3366, Val: 0.3807
# Epoch: 046, Loss: 0.1133, Train: 0.3358, Val: 0.3811
# Epoch: 047, Loss: 0.1128, Train: 0.3352, Val: 0.3811
# Epoch: 048, Loss: 0.1124, Train: 0.3345, Val: 0.3805
# Epoch: 049, Loss: 0.1119, Train: 0.3338, Val: 0.3791
# Epoch: 050, Loss: 0.1114, Train: 0.3329, Val: 0.3772
# Epoch: 051, Loss: 0.1109, Train: 0.3320, Val: 0.3753
# Epoch: 052, Loss: 0.1103, Train: 0.3312, Val: 0.3740
# Epoch: 053, Loss: 0.1097, Train: 0.3304, Val: 0.3732
# Epoch: 054, Loss: 0.1092, Train: 0.3297, Val: 0.3725
# Epoch: 055, Loss: 0.1087, Train: 0.3290, Val: 0.3716
# Epoch: 056, Loss: 0.1083, Train: 0.3283, Val: 0.3703
# Epoch: 057, Loss: 0.1078, Train: 0.3276, Val: 0.3692
# Epoch: 058, Loss: 0.1073, Train: 0.3268, Val: 0.3685
# Epoch: 059, Loss: 0.1068, Train: 0.3261, Val: 0.3683
# Epoch: 060, Loss: 0.1063, Train: 0.3253, Val: 0.3679
# Epoch: 061, Loss: 0.1058, Train: 0.3245, Val: 0.3670
# Epoch: 062, Loss: 0.1053, Train: 0.3236, Val: 0.3658
# Epoch: 063, Loss: 0.1047, Train: 0.3228, Val: 0.3651
# Epoch: 064, Loss: 0.1042, Train: 0.3219, Val: 0.3648
# Epoch: 065, Loss: 0.1036, Train: 0.3210, Val: 0.3643
# Epoch: 066, Loss: 0.1030, Train: 0.3200, Val: 0.3632
# Epoch: 067, Loss: 0.1024, Train: 0.3191, Val: 0.3622
# Epoch: 068, Loss: 0.1018, Train: 0.3181, Val: 0.3616
# Epoch: 069, Loss: 0.1012, Train: 0.3172, Val: 0.3612
# Epoch: 070, Loss: 0.1006, Train: 0.3162, Val: 0.3602
# Epoch: 071, Loss: 0.1000, Train: 0.3152, Val: 0.3591
# Epoch: 072, Loss: 0.0994, Train: 0.3142, Val: 0.3585
# Epoch: 073, Loss: 0.0987, Train: 0.3133, Val: 0.3580
# Epoch: 074, Loss: 0.0981, Train: 0.3123, Val: 0.3570
# Epoch: 075, Loss: 0.0975, Train: 0.3113, Val: 0.3560
# Epoch: 076, Loss: 0.0969, Train: 0.3102, Val: 0.3556
# Epoch: 077, Loss: 0.0963, Train: 0.3092, Val: 0.3548
# Epoch: 078, Loss: 0.0956, Train: 0.3082, Val: 0.3536
# Epoch: 079, Loss: 0.0950, Train: 0.3071, Val: 0.3529
# Epoch: 080, Loss: 0.0943, Train: 0.3061, Val: 0.3521
# Epoch: 081, Loss: 0.0937, Train: 0.3050, Val: 0.3507
# Epoch: 082, Loss: 0.0930, Train: 0.3039, Val: 0.3500
# Epoch: 083, Loss: 0.0924, Train: 0.3029, Val: 0.3490
# Epoch: 084, Loss: 0.0917, Train: 0.3018, Val: 0.3478
# Epoch: 085, Loss: 0.0911, Train: 0.3007, Val: 0.3473
# Epoch: 086, Loss: 0.0904, Train: 0.2997, Val: 0.3457
# Epoch: 087, Loss: 0.0898, Train: 0.2986, Val: 0.3457
# Epoch: 088, Loss: 0.0892, Train: 0.2976, Val: 0.3434
# Epoch: 089, Loss: 0.0886, Train: 0.2967, Val: 0.3444
# Epoch: 090, Loss: 0.0880, Train: 0.2956, Val: 0.3413
# Epoch: 091, Loss: 0.0874, Train: 0.2945, Val: 0.3420
# Epoch: 092, Loss: 0.0867, Train: 0.2934, Val: 0.3404
# Epoch: 093, Loss: 0.0861, Train: 0.2925, Val: 0.3388
# Epoch: 094, Loss: 0.0856, Train: 0.2917, Val: 0.3397
# Epoch: 095, Loss: 0.0851, Train: 0.2908, Val: 0.3368
# Epoch: 096, Loss: 0.0846, Train: 0.2897, Val: 0.3376
# Epoch: 097, Loss: 0.0840, Train: 0.2888, Val: 0.3360
# Epoch: 098, Loss: 0.0834, Train: 0.2880, Val: 0.3348
# Epoch: 099, Loss: 0.0829, Train: 0.2873, Val: 0.3356
# Epoch: 100, Loss: 0.0825, Train: 0.2865, Val: 0.3329
# Epoch: 101, Loss: 0.0821, Train: 0.2856, Val: 0.3346
# Epoch: 102, Loss: 0.0816, Train: 0.2845, Val: 0.3315
# Epoch: 103, Loss: 0.0810, Train: 0.2835, Val: 0.3321
# Epoch: 104, Loss: 0.0804, Train: 0.2827, Val: 0.3304
# Epoch: 105, Loss: 0.0800, Train: 0.2820, Val: 0.3294
# Epoch: 106, Loss: 0.0796, Train: 0.2815, Val: 0.3296
# Epoch: 107, Loss: 0.0793, Train: 0.2812, Val: 0.3273
# Epoch: 108, Loss: 0.0792, Train: 0.2813, Val: 0.3303
# Epoch: 109, Loss: 0.0794, Train: 0.2821, Val: 0.3262
# Epoch: 110, Loss: 0.0797, Train: 0.2808, Val: 0.3298
# Epoch: 111, Loss: 0.0792, Train: 0.2789, Val: 0.3256
# Epoch: 112, Loss: 0.0781, Train: 0.2791, Val: 0.3248
# Epoch: 113, Loss: 0.0782, Train: 0.2799, Val: 0.3283
# Epoch: 114, Loss: 0.0788, Train: 0.2798, Val: 0.3241
# Epoch: 115, Loss: 0.0786, Train: 0.2779, Val: 0.3250
# Epoch: 116, Loss: 0.0777, Train: 0.2780, Val: 0.3255
# Epoch: 117, Loss: 0.0778, Train: 0.2792, Val: 0.3237
# Epoch: 118, Loss: 0.0783, Train: 0.2780, Val: 0.3258
# Epoch: 119, Loss: 0.0778, Train: 0.2772, Val: 0.3242
# Epoch: 120, Loss: 0.0773, Train: 0.2779, Val: 0.3236
# Epoch: 121, Loss: 0.0776, Train: 0.2777, Val: 0.3261
# Epoch: 122, Loss: 0.0776, Train: 0.2771, Val: 0.3241
# Epoch: 123, Loss: 0.0772, Train: 0.2771, Val: 0.3241
# Epoch: 124, Loss: 0.0772, Train: 0.2772, Val: 0.3262
# Epoch: 125, Loss: 0.0774, Train: 0.2770, Val: 0.3244
# Epoch: 126, Loss: 0.0771, Train: 0.2767, Val: 0.3248
# Epoch: 127, Loss: 0.0770, Train: 0.2769, Val: 0.3263
# Epoch: 128, Loss: 0.0771, Train: 0.2768, Val: 0.3247
# Epoch: 129, Loss: 0.0770, Train: 0.2764, Val: 0.3253
# Epoch: 130, Loss: 0.0768, Train: 0.2766, Val: 0.3263
# Epoch: 131, Loss: 0.0770, Train: 0.2767, Val: 0.3249
# Epoch: 132, Loss: 0.0769, Train: 0.2763, Val: 0.3255
# Epoch: 133, Loss: 0.0767, Train: 0.2763, Val: 0.3261
# Epoch: 134, Loss: 0.0768, Train: 0.2765, Val: 0.3248
# Epoch: 135, Loss: 0.0768, Train: 0.2761, Val: 0.3253
# Epoch: 136, Loss: 0.0767, Train: 0.2761, Val: 0.3254
# Epoch: 137, Loss: 0.0767, Train: 0.2763, Val: 0.3243
# Epoch: 138, Loss: 0.0767, Train: 0.2759, Val: 0.3249
# Epoch: 139, Loss: 0.0766, Train: 0.2758, Val: 0.3247
# Epoch: 140, Loss: 0.0765, Train: 0.2760, Val: 0.3239
# Epoch: 141, Loss: 0.0766, Train: 0.2758, Val: 0.3246
# Epoch: 142, Loss: 0.0765, Train: 0.2757, Val: 0.3240
# Epoch: 143, Loss: 0.0764, Train: 0.2757, Val: 0.3235
# Epoch: 144, Loss: 0.0764, Train: 0.2756, Val: 0.3241
# Epoch: 145, Loss: 0.0764, Train: 0.2756, Val: 0.3232
# Epoch: 146, Loss: 0.0764, Train: 0.2755, Val: 0.3231
# Epoch: 147, Loss: 0.0763, Train: 0.2754, Val: 0.3233
# Epoch: 148, Loss: 0.0763, Train: 0.2755, Val: 0.3224
# Epoch: 149, Loss: 0.0763, Train: 0.2753, Val: 0.3227
# Epoch: 150, Loss: 0.0762, Train: 0.2753, Val: 0.3225
# Epoch: 151, Loss: 0.0762, Train: 0.2753, Val: 0.3220
# Epoch: 152, Loss: 0.0762, Train: 0.2752, Val: 0.3225
# Epoch: 153, Loss: 0.0762, Train: 0.2752, Val: 0.3220
# Epoch: 154, Loss: 0.0761, Train: 0.2751, Val: 0.3219
# Epoch: 155, Loss: 0.0761, Train: 0.2751, Val: 0.3221
# Epoch: 156, Loss: 0.0761, Train: 0.2751, Val: 0.3215
# Epoch: 157, Loss: 0.0761, Train: 0.2750, Val: 0.3218
# Epoch: 158, Loss: 0.0760, Train: 0.2749, Val: 0.3214
# Epoch: 159, Loss: 0.0760, Train: 0.2749, Val: 0.3212
# Epoch: 160, Loss: 0.0760, Train: 0.2748, Val: 0.3215
# Epoch: 161, Loss: 0.0760, Train: 0.2748, Val: 0.3210
# Epoch: 162, Loss: 0.0759, Train: 0.2747, Val: 0.3212
# Epoch: 163, Loss: 0.0759, Train: 0.2747, Val: 0.3211
# Epoch: 164, Loss: 0.0759, Train: 0.2747, Val: 0.3209
# Epoch: 165, Loss: 0.0759, Train: 0.2746, Val: 0.3210
# Epoch: 166, Loss: 0.0758, Train: 0.2746, Val: 0.3206
# Epoch: 167, Loss: 0.0758, Train: 0.2745, Val: 0.3207
# Epoch: 168, Loss: 0.0758, Train: 0.2745, Val: 0.3205
# Epoch: 169, Loss: 0.0758, Train: 0.2745, Val: 0.3204
# Epoch: 170, Loss: 0.0757, Train: 0.2744, Val: 0.3205
# Epoch: 171, Loss: 0.0757, Train: 0.2744, Val: 0.3202
# Epoch: 172, Loss: 0.0757, Train: 0.2743, Val: 0.3204
# Epoch: 173, Loss: 0.0757, Train: 0.2743, Val: 0.3201
# Epoch: 174, Loss: 0.0756, Train: 0.2743, Val: 0.3200
# Epoch: 175, Loss: 0.0756, Train: 0.2742, Val: 0.3200
# Epoch: 176, Loss: 0.0756, Train: 0.2742, Val: 0.3198
# Epoch: 177, Loss: 0.0756, Train: 0.2741, Val: 0.3199
# Epoch: 178, Loss: 0.0756, Train: 0.2741, Val: 0.3197
# Epoch: 179, Loss: 0.0755, Train: 0.2740, Val: 0.3198
# Epoch: 180, Loss: 0.0755, Train: 0.2740, Val: 0.3196
# Epoch: 181, Loss: 0.0755, Train: 0.2740, Val: 0.3196
# Epoch: 182, Loss: 0.0755, Train: 0.2739, Val: 0.3195
# Epoch: 183, Loss: 0.0754, Train: 0.2739, Val: 0.3192
# Epoch: 184, Loss: 0.0754, Train: 0.2738, Val: 0.3193
# Epoch: 185, Loss: 0.0754, Train: 0.2738, Val: 0.3190
# Epoch: 186, Loss: 0.0754, Train: 0.2738, Val: 0.3192
# Epoch: 187, Loss: 0.0754, Train: 0.2737, Val: 0.3190
# Epoch: 188, Loss: 0.0753, Train: 0.2737, Val: 0.3191
# Epoch: 189, Loss: 0.0753, Train: 0.2737, Val: 0.3189
# Epoch: 190, Loss: 0.0753, Train: 0.2736, Val: 0.3190
# Epoch: 191, Loss: 0.0753, Train: 0.2736, Val: 0.3187
# Epoch: 192, Loss: 0.0753, Train: 0.2735, Val: 0.3189
# Epoch: 193, Loss: 0.0752, Train: 0.2735, Val: 0.3186
# Epoch: 194, Loss: 0.0752, Train: 0.2734, Val: 0.3189
# Epoch: 195, Loss: 0.0752, Train: 0.2735, Val: 0.3185
# Epoch: 196, Loss: 0.0752, Train: 0.2734, Val: 0.3190
# Epoch: 197, Loss: 0.0752, Train: 0.2734, Val: 0.3183
# Epoch: 198, Loss: 0.0752, Train: 0.2734, Val: 0.3191
# Epoch: 199, Loss: 0.0752, Train: 0.2736, Val: 0.3180
# Epoch: 200, Loss: 0.0752, Train: 0.2736, Val: 0.3197
# Epoch: 201, Loss: 0.0753, Train: 0.2743, Val: 0.3179
# Epoch: 202, Loss: 0.0756, Train: 0.2746, Val: 0.3213
# Epoch: 203, Loss: 0.0759, Train: 0.2758, Val: 0.3184
# Epoch: 204, Loss: 0.0764, Train: 0.2752, Val: 0.3222
# Epoch: 205, Loss: 0.0763, Train: 0.2746, Val: 0.3184
# Epoch: 206, Loss: 0.0758, Train: 0.2732, Val: 0.3197
# Epoch: 207, Loss: 0.0751, Train: 0.2731, Val: 0.3196
# Epoch: 208, Loss: 0.0750, Train: 0.2741, Val: 0.3185
# Epoch: 209, Loss: 0.0754, Train: 0.2740, Val: 0.3213
# Epoch: 210, Loss: 0.0756, Train: 0.2737, Val: 0.3185
# Epoch: 211, Loss: 0.0752, Train: 0.2729, Val: 0.3193
# Epoch: 212, Loss: 0.0749, Train: 0.2731, Val: 0.3199
# Epoch: 213, Loss: 0.0750, Train: 0.2737, Val: 0.3185
# Epoch: 214, Loss: 0.0753, Train: 0.2733, Val: 0.3204
# Epoch: 215, Loss: 0.0752, Train: 0.2729, Val: 0.3186
# Epoch: 216, Loss: 0.0749, Train: 0.2728, Val: 0.3186
# Epoch: 217, Loss: 0.0748, Train: 0.2730, Val: 0.3197
# Epoch: 218, Loss: 0.0750, Train: 0.2733, Val: 0.3179
# Epoch: 219, Loss: 0.0751, Train: 0.2728, Val: 0.3192
# Epoch: 220, Loss: 0.0749, Train: 0.2726, Val: 0.3177
# Epoch: 221, Loss: 0.0747, Train: 0.2726, Val: 0.3175
# Epoch: 222, Loss: 0.0747, Train: 0.2727, Val: 0.3184
# Epoch: 223, Loss: 0.0748, Train: 0.2729, Val: 0.3171
# Epoch: 224, Loss: 0.0748, Train: 0.2726, Val: 0.3183
# Epoch: 225, Loss: 0.0748, Train: 0.2725, Val: 0.3175
# Epoch: 226, Loss: 0.0747, Train: 0.2724, Val: 0.3178
# Epoch: 227, Loss: 0.0746, Train: 0.2725, Val: 0.3187
# Epoch: 228, Loss: 0.0747, Train: 0.2726, Val: 0.3179
# Epoch: 229, Loss: 0.0747, Train: 0.2724, Val: 0.3189
# Epoch: 230, Loss: 0.0747, Train: 0.2724, Val: 0.3178
# Epoch: 231, Loss: 0.0746, Train: 0.2723, Val: 0.3178
# Epoch: 232, Loss: 0.0745, Train: 0.2723, Val: 0.3177
# Epoch: 233, Loss: 0.0745, Train: 0.2724, Val: 0.3170
# Epoch: 234, Loss: 0.0746, Train: 0.2723, Val: 0.3177
# Epoch: 235, Loss: 0.0746, Train: 0.2723, Val: 0.3170
# Epoch: 236, Loss: 0.0745, Train: 0.2721, Val: 0.3175
# Epoch: 237, Loss: 0.0745, Train: 0.2721, Val: 0.3175
# Epoch: 238, Loss: 0.0745, Train: 0.2721, Val: 0.3174
# Epoch: 239, Loss: 0.0744, Train: 0.2721, Val: 0.3180
# Epoch: 240, Loss: 0.0745, Train: 0.2721, Val: 0.3172
# Epoch: 241, Loss: 0.0744, Train: 0.2720, Val: 0.3177
# Epoch: 242, Loss: 0.0744, Train: 0.2720, Val: 0.3168
# Epoch: 243, Loss: 0.0744, Train: 0.2719, Val: 0.3166
# Epoch: 244, Loss: 0.0744, Train: 0.2719, Val: 0.3163
# Epoch: 245, Loss: 0.0743, Train: 0.2719, Val: 0.3159
# Epoch: 246, Loss: 0.0743, Train: 0.2718, Val: 0.3162
# Epoch: 247, Loss: 0.0743, Train: 0.2719, Val: 0.3157
# Epoch: 248, Loss: 0.0743, Train: 0.2718, Val: 0.3163
# Epoch: 249, Loss: 0.0743, Train: 0.2718, Val: 0.3161
# Epoch: 250, Loss: 0.0743, Train: 0.2717, Val: 0.3167
# Epoch: 251, Loss: 0.0742, Train: 0.2717, Val: 0.3167
# Epoch: 252, Loss: 0.0742, Train: 0.2717, Val: 0.3168
# Epoch: 253, Loss: 0.0742, Train: 0.2716, Val: 0.3168
# Epoch: 254, Loss: 0.0742, Train: 0.2716, Val: 0.3164
# Epoch: 255, Loss: 0.0742, Train: 0.2716, Val: 0.3165
# Epoch: 256, Loss: 0.0742, Train: 0.2716, Val: 0.3158
# Epoch: 257, Loss: 0.0742, Train: 0.2715, Val: 0.3160
# Epoch: 258, Loss: 0.0742, Train: 0.2716, Val: 0.3155
# Epoch: 259, Loss: 0.0741, Train: 0.2715, Val: 0.3159
# Epoch: 260, Loss: 0.0741, Train: 0.2715, Val: 0.3156
# Epoch: 261, Loss: 0.0741, Train: 0.2714, Val: 0.3163
# Epoch: 262, Loss: 0.0741, Train: 0.2715, Val: 0.3159
# Epoch: 263, Loss: 0.0741, Train: 0.2714, Val: 0.3164
# Epoch: 264, Loss: 0.0741, Train: 0.2714, Val: 0.3158
# Epoch: 265, Loss: 0.0741, Train: 0.2714, Val: 0.3165
# Epoch: 266, Loss: 0.0741, Train: 0.2715, Val: 0.3156
# Epoch: 267, Loss: 0.0741, Train: 0.2714, Val: 0.3166
# Epoch: 268, Loss: 0.0741, Train: 0.2715, Val: 0.3156
# Epoch: 269, Loss: 0.0741, Train: 0.2715, Val: 0.3170
# Epoch: 270, Loss: 0.0741, Train: 0.2718, Val: 0.3156
# Epoch: 271, Loss: 0.0742, Train: 0.2718, Val: 0.3178
# Epoch: 272, Loss: 0.0743, Train: 0.2723, Val: 0.3158
# Epoch: 273, Loss: 0.0745, Train: 0.2723, Val: 0.3189
# Epoch: 274, Loss: 0.0746, Train: 0.2729, Val: 0.3162
# Epoch: 275, Loss: 0.0748, Train: 0.2723, Val: 0.3193
# Epoch: 276, Loss: 0.0746, Train: 0.2722, Val: 0.3162
# Epoch: 277, Loss: 0.0744, Train: 0.2713, Val: 0.3178
# Epoch: 278, Loss: 0.0740, Train: 0.2711, Val: 0.3164
# Epoch: 279, Loss: 0.0738, Train: 0.2711, Val: 0.3161
# Epoch: 280, Loss: 0.0739, Train: 0.2713, Val: 0.3172
# Epoch: 281, Loss: 0.0740, Train: 0.2717, Val: 0.3152
# Epoch: 282, Loss: 0.0742, Train: 0.2714, Val: 0.3169
# Epoch: 283, Loss: 0.0741, Train: 0.2714, Val: 0.3145
# Epoch: 284, Loss: 0.0740, Train: 0.2710, Val: 0.3154
# Epoch: 285, Loss: 0.0738, Train: 0.2708, Val: 0.3146
# Epoch: 286, Loss: 0.0737, Train: 0.2708, Val: 0.3146
# Epoch: 287, Loss: 0.0737, Train: 0.2709, Val: 0.3158
# Epoch: 288, Loss: 0.0738, Train: 0.2712, Val: 0.3149
# Epoch: 289, Loss: 0.0739, Train: 0.2710, Val: 0.3168
# Epoch: 290, Loss: 0.0739, Train: 0.2712, Val: 0.3152
# Epoch: 291, Loss: 0.0739, Train: 0.2709, Val: 0.3166
# Epoch: 292, Loss: 0.0738, Train: 0.2708, Val: 0.3148
# Epoch: 293, Loss: 0.0737, Train: 0.2706, Val: 0.3149
# Epoch: 294, Loss: 0.0736, Train: 0.2706, Val: 0.3140
# Epoch: 295, Loss: 0.0736, Train: 0.2706, Val: 0.3134
# Epoch: 296, Loss: 0.0736, Train: 0.2706, Val: 0.3137
# Epoch: 297, Loss: 0.0736, Train: 0.2707, Val: 0.3129
# Epoch: 298, Loss: 0.0736, Train: 0.2706, Val: 0.3141
# Epoch: 299, Loss: 0.0736, Train: 0.2708, Val: 0.3132
# Epoch: 300, Loss: 0.0736, Train: 0.2706, Val: 0.3147
# Epoch: 301, Loss: 0.0736, Train: 0.2707, Val: 0.3137
# Epoch: 302, Loss: 0.0736, Train: 0.2705, Val: 0.3149
# Epoch: 303, Loss: 0.0735, Train: 0.2705, Val: 0.3140
# Epoch: 304, Loss: 0.0735, Train: 0.2703, Val: 0.3143
# Epoch: 305, Loss: 0.0735, Train: 0.2703, Val: 0.3137
# Epoch: 306, Loss: 0.0734, Train: 0.2703, Val: 0.3134
# Epoch: 307, Loss: 0.0734, Train: 0.2702, Val: 0.3132
# Epoch: 308, Loss: 0.0734, Train: 0.2703, Val: 0.3124
# Epoch: 309, Loss: 0.0734, Train: 0.2702, Val: 0.3128
# Epoch: 310, Loss: 0.0734, Train: 0.2703, Val: 0.3120
# Epoch: 311, Loss: 0.0734, Train: 0.2703, Val: 0.3130
# Epoch: 312, Loss: 0.0734, Train: 0.2704, Val: 0.3119
# Epoch: 313, Loss: 0.0735, Train: 0.2704, Val: 0.3135
# Epoch: 314, Loss: 0.0735, Train: 0.2707, Val: 0.3121
# Epoch: 315, Loss: 0.0736, Train: 0.2706, Val: 0.3142
# Epoch: 316, Loss: 0.0736, Train: 0.2710, Val: 0.3120
# Epoch: 317, Loss: 0.0737, Train: 0.2708, Val: 0.3146
# Epoch: 318, Loss: 0.0738, Train: 0.2712, Val: 0.3122
# Epoch: 319, Loss: 0.0738, Train: 0.2708, Val: 0.3150
# Epoch: 320, Loss: 0.0738, Train: 0.2709, Val: 0.3128
# Epoch: 321, Loss: 0.0737, Train: 0.2703, Val: 0.3152
# Epoch: 322, Loss: 0.0735, Train: 0.2702, Val: 0.3139
# Epoch: 323, Loss: 0.0733, Train: 0.2699, Val: 0.3150
# Epoch: 324, Loss: 0.0732, Train: 0.2698, Val: 0.3152
# Epoch: 325, Loss: 0.0732, Train: 0.2700, Val: 0.3144
# Epoch: 326, Loss: 0.0732, Train: 0.2700, Val: 0.3157
# Epoch: 327, Loss: 0.0733, Train: 0.2703, Val: 0.3140
# Epoch: 328, Loss: 0.0734, Train: 0.2701, Val: 0.3158
# Epoch: 329, Loss: 0.0734, Train: 0.2703, Val: 0.3138
# Epoch: 330, Loss: 0.0733, Train: 0.2700, Val: 0.3154
# Epoch: 331, Loss: 0.0733, Train: 0.2700, Val: 0.3137
# Epoch: 332, Loss: 0.0732, Train: 0.2697, Val: 0.3150
# Epoch: 333, Loss: 0.0731, Train: 0.2697, Val: 0.3141
# Epoch: 334, Loss: 0.0731, Train: 0.2696, Val: 0.3146
# Epoch: 335, Loss: 0.0730, Train: 0.2695, Val: 0.3145
# Epoch: 336, Loss: 0.0730, Train: 0.2696, Val: 0.3143
# Epoch: 337, Loss: 0.0730, Train: 0.2695, Val: 0.3148
# Epoch: 338, Loss: 0.0730, Train: 0.2696, Val: 0.3142
# Epoch: 339, Loss: 0.0730, Train: 0.2696, Val: 0.3153
# Epoch: 340, Loss: 0.0730, Train: 0.2697, Val: 0.3141
# Epoch: 341, Loss: 0.0731, Train: 0.2697, Val: 0.3157
# Epoch: 342, Loss: 0.0731, Train: 0.2699, Val: 0.3142
# Epoch: 343, Loss: 0.0731, Train: 0.2698, Val: 0.3163
# Epoch: 344, Loss: 0.0732, Train: 0.2702, Val: 0.3142
# Epoch: 345, Loss: 0.0733, Train: 0.2700, Val: 0.3167
# Epoch: 346, Loss: 0.0733, Train: 0.2703, Val: 0.3142
# Epoch: 347, Loss: 0.0733, Train: 0.2700, Val: 0.3168
# Epoch: 348, Loss: 0.0733, Train: 0.2701, Val: 0.3144
# Epoch: 349, Loss: 0.0732, Train: 0.2696, Val: 0.3164
# Epoch: 350, Loss: 0.0731, Train: 0.2695, Val: 0.3146
# Epoch: 351, Loss: 0.0729, Train: 0.2692, Val: 0.3157
# Epoch: 352, Loss: 0.0728, Train: 0.2692, Val: 0.3152
# Epoch: 353, Loss: 0.0728, Train: 0.2692, Val: 0.3150
# Epoch: 354, Loss: 0.0728, Train: 0.2692, Val: 0.3157
# Epoch: 355, Loss: 0.0728, Train: 0.2694, Val: 0.3145
# Epoch: 356, Loss: 0.0729, Train: 0.2694, Val: 0.3161
# Epoch: 357, Loss: 0.0729, Train: 0.2696, Val: 0.3142
# Epoch: 358, Loss: 0.0730, Train: 0.2695, Val: 0.3163
# Epoch: 359, Loss: 0.0730, Train: 0.2697, Val: 0.3141
# Epoch: 360, Loss: 0.0730, Train: 0.2695, Val: 0.3163
# Epoch: 361, Loss: 0.0730, Train: 0.2697, Val: 0.3140
# Epoch: 362, Loss: 0.0730, Train: 0.2694, Val: 0.3163
# Epoch: 363, Loss: 0.0729, Train: 0.2695, Val: 0.3140
# Epoch: 364, Loss: 0.0729, Train: 0.2692, Val: 0.3160
# Epoch: 365, Loss: 0.0728, Train: 0.2692, Val: 0.3140
# Epoch: 366, Loss: 0.0728, Train: 0.2690, Val: 0.3154
# Epoch: 367, Loss: 0.0727, Train: 0.2690, Val: 0.3143
# Epoch: 368, Loss: 0.0726, Train: 0.2688, Val: 0.3151
# Epoch: 369, Loss: 0.0726, Train: 0.2688, Val: 0.3146
# Epoch: 370, Loss: 0.0725, Train: 0.2687, Val: 0.3144
# Epoch: 371, Loss: 0.0725, Train: 0.2687, Val: 0.3145
# Epoch: 372, Loss: 0.0725, Train: 0.2688, Val: 0.3138
# Epoch: 373, Loss: 0.0725, Train: 0.2687, Val: 0.3146
# Epoch: 374, Loss: 0.0725, Train: 0.2689, Val: 0.3135
# Epoch: 375, Loss: 0.0725, Train: 0.2688, Val: 0.3150
# Epoch: 376, Loss: 0.0726, Train: 0.2691, Val: 0.3132
# Epoch: 377, Loss: 0.0726, Train: 0.2690, Val: 0.3153
# Epoch: 378, Loss: 0.0727, Train: 0.2695, Val: 0.3129
# Epoch: 379, Loss: 0.0729, Train: 0.2696, Val: 0.3160
# Epoch: 380, Loss: 0.0730, Train: 0.2704, Val: 0.3129
# Epoch: 381, Loss: 0.0733, Train: 0.2703, Val: 0.3168
# Epoch: 382, Loss: 0.0734, Train: 0.2709, Val: 0.3129
# Epoch: 383, Loss: 0.0736, Train: 0.2700, Val: 0.3166
# Epoch: 384, Loss: 0.0733, Train: 0.2697, Val: 0.3130
# Epoch: 385, Loss: 0.0729, Train: 0.2687, Val: 0.3150
# Epoch: 386, Loss: 0.0725, Train: 0.2684, Val: 0.3141
# Epoch: 387, Loss: 0.0723, Train: 0.2687, Val: 0.3134
# Epoch: 388, Loss: 0.0724, Train: 0.2690, Val: 0.3156
# Epoch: 389, Loss: 0.0727, Train: 0.2694, Val: 0.3129
# Epoch: 390, Loss: 0.0728, Train: 0.2689, Val: 0.3154
# Epoch: 391, Loss: 0.0726, Train: 0.2687, Val: 0.3131
# Epoch: 392, Loss: 0.0724, Train: 0.2683, Val: 0.3139
# Epoch: 393, Loss: 0.0722, Train: 0.2682, Val: 0.3137
# Epoch: 394, Loss: 0.0722, Train: 0.2685, Val: 0.3127
# Epoch: 395, Loss: 0.0723, Train: 0.2686, Val: 0.3145
# Epoch: 396, Loss: 0.0724, Train: 0.2689, Val: 0.3122
# Epoch: 397, Loss: 0.0725, Train: 0.2686, Val: 0.3145
# Epoch: 398, Loss: 0.0725, Train: 0.2687, Val: 0.3120
# Epoch: 399, Loss: 0.0724, Train: 0.2683, Val: 0.3136
# Epoch: 400, Loss: 0.0723, Train: 0.2682, Val: 0.3122
# Epoch: 401, Loss: 0.0722, Train: 0.2680, Val: 0.3127
# Epoch: 402, Loss: 0.0721, Train: 0.2680, Val: 0.3126
# Epoch: 403, Loss: 0.0721, Train: 0.2681, Val: 0.3122
# Epoch: 404, Loss: 0.0721, Train: 0.2681, Val: 0.3133
# Epoch: 405, Loss: 0.0721, Train: 0.2682, Val: 0.3114
# Epoch: 406, Loss: 0.0722, Train: 0.2682, Val: 0.3128
# Epoch: 407, Loss: 0.0722, Train: 0.2683, Val: 0.3107
# Epoch: 408, Loss: 0.0722, Train: 0.2682, Val: 0.3125
# Epoch: 409, Loss: 0.0722, Train: 0.2683, Val: 0.3110
# Epoch: 410, Loss: 0.0722, Train: 0.2681, Val: 0.3131
# Epoch: 411, Loss: 0.0721, Train: 0.2681, Val: 0.3109
# Epoch: 412, Loss: 0.0721, Train: 0.2679, Val: 0.3119
# Epoch: 413, Loss: 0.0720, Train: 0.2680, Val: 0.3103
# Epoch: 414, Loss: 0.0720, Train: 0.2678, Val: 0.3115
# Epoch: 415, Loss: 0.0720, Train: 0.2678, Val: 0.3106
# Epoch: 416, Loss: 0.0720, Train: 0.2677, Val: 0.3118
# Epoch: 417, Loss: 0.0719, Train: 0.2678, Val: 0.3106
# Epoch: 418, Loss: 0.0719, Train: 0.2677, Val: 0.3111
# Epoch: 419, Loss: 0.0719, Train: 0.2678, Val: 0.3097
# Epoch: 420, Loss: 0.0719, Train: 0.2678, Val: 0.3110
# Epoch: 421, Loss: 0.0719, Train: 0.2681, Val: 0.3096
# Epoch: 422, Loss: 0.0720, Train: 0.2683, Val: 0.3126
# Epoch: 423, Loss: 0.0722, Train: 0.2695, Val: 0.3093
# Epoch: 424, Loss: 0.0728, Train: 0.2706, Val: 0.3149
# Epoch: 425, Loss: 0.0736, Train: 0.2740, Val: 0.3103
# Epoch: 426, Loss: 0.0752, Train: 0.2729, Val: 0.3166
# Epoch: 427, Loss: 0.0749, Train: 0.2721, Val: 0.3088
# Epoch: 428, Loss: 0.0741, Train: 0.2680, Val: 0.3101
# Epoch: 429, Loss: 0.0721, Train: 0.2681, Val: 0.3107
# Epoch: 430, Loss: 0.0722, Train: 0.2709, Val: 0.3090
# Epoch: 431, Loss: 0.0735, Train: 0.2691, Val: 0.3133
# Epoch: 432, Loss: 0.0727, Train: 0.2676, Val: 0.3094
# Epoch: 433, Loss: 0.0718, Train: 0.2684, Val: 0.3086
# Epoch: 434, Loss: 0.0722, Train: 0.2690, Val: 0.3123
# Epoch: 435, Loss: 0.0726, Train: 0.2688, Val: 0.3082
# Epoch: 436, Loss: 0.0724, Train: 0.2674, Val: 0.3097
# Epoch: 437, Loss: 0.0717, Train: 0.2674, Val: 0.3101
# Epoch: 438, Loss: 0.0718, Train: 0.2686, Val: 0.3084
# Epoch: 439, Loss: 0.0723, Train: 0.2686, Val: 0.3124
# Epoch: 440, Loss: 0.0725, Train: 0.2685, Val: 0.3082
# Epoch: 441, Loss: 0.0723, Train: 0.2674, Val: 0.3099
# Epoch: 442, Loss: 0.0718, Train: 0.2671, Val: 0.3087
# Epoch: 443, Loss: 0.0716, Train: 0.2675, Val: 0.3081
# Epoch: 444, Loss: 0.0718, Train: 0.2678, Val: 0.3108
# Epoch: 445, Loss: 0.0720, Train: 0.2681, Val: 0.3073
# Epoch: 446, Loss: 0.0721, Train: 0.2675, Val: 0.3089
# Epoch: 447, Loss: 0.0718, Train: 0.2671, Val: 0.3068
# Epoch: 448, Loss: 0.0716, Train: 0.2670, Val: 0.3070
# Epoch: 449, Loss: 0.0715, Train: 0.2672, Val: 0.3084
# Epoch: 450, Loss: 0.0717, Train: 0.2676, Val: 0.3069
# Epoch: 451, Loss: 0.0718, Train: 0.2673, Val: 0.3088
# Epoch: 452, Loss: 0.0717, Train: 0.2671, Val: 0.3060
# Epoch: 453, Loss: 0.0715, Train: 0.2669, Val: 0.3057
# Epoch: 454, Loss: 0.0714, Train: 0.2669, Val: 0.3056
# Epoch: 455, Loss: 0.0715, Train: 0.2672, Val: 0.3045
# Epoch: 456, Loss: 0.0716, Train: 0.2671, Val: 0.3062
# Epoch: 457, Loss: 0.0716, Train: 0.2672, Val: 0.3047
# Epoch: 458, Loss: 0.0716, Train: 0.2669, Val: 0.3065
# Epoch: 459, Loss: 0.0715, Train: 0.2669, Val: 0.3057
# Epoch: 460, Loss: 0.0714, Train: 0.2667, Val: 0.3061
# Epoch: 461, Loss: 0.0714, Train: 0.2667, Val: 0.3062
# Epoch: 462, Loss: 0.0714, Train: 0.2668, Val: 0.3055
# Epoch: 463, Loss: 0.0714, Train: 0.2668, Val: 0.3061
# Epoch: 464, Loss: 0.0714, Train: 0.2670, Val: 0.3042
# Epoch: 465, Loss: 0.0714, Train: 0.2669, Val: 0.3054
# Epoch: 466, Loss: 0.0715, Train: 0.2670, Val: 0.3038
# Epoch: 467, Loss: 0.0715, Train: 0.2668, Val: 0.3053
# Epoch: 468, Loss: 0.0714, Train: 0.2669, Val: 0.3039
# Epoch: 469, Loss: 0.0714, Train: 0.2667, Val: 0.3057
# Epoch: 470, Loss: 0.0714, Train: 0.2668, Val: 0.3044
# Epoch: 471, Loss: 0.0713, Train: 0.2666, Val: 0.3052
# Epoch: 472, Loss: 0.0713, Train: 0.2666, Val: 0.3037
# Epoch: 473, Loss: 0.0712, Train: 0.2665, Val: 0.3040
# Epoch: 474, Loss: 0.0712, Train: 0.2665, Val: 0.3036
# Epoch: 475, Loss: 0.0712, Train: 0.2664, Val: 0.3041
# Epoch: 476, Loss: 0.0712, Train: 0.2664, Val: 0.3045
# Epoch: 477, Loss: 0.0712, Train: 0.2664, Val: 0.3046
# Epoch: 478, Loss: 0.0712, Train: 0.2664, Val: 0.3046
# Epoch: 479, Loss: 0.0712, Train: 0.2664, Val: 0.3037
# Epoch: 480, Loss: 0.0712, Train: 0.2664, Val: 0.3042
# Epoch: 481, Loss: 0.0712, Train: 0.2665, Val: 0.3034
# Epoch: 482, Loss: 0.0712, Train: 0.2666, Val: 0.3053
# Epoch: 483, Loss: 0.0713, Train: 0.2671, Val: 0.3035
# Epoch: 484, Loss: 0.0715, Train: 0.2677, Val: 0.3071
# Epoch: 485, Loss: 0.0719, Train: 0.2699, Val: 0.3041
# Epoch: 486, Loss: 0.0730, Train: 0.2714, Val: 0.3116
# Epoch: 487, Loss: 0.0740, Train: 0.2751, Val: 0.3054
# Epoch: 488, Loss: 0.0757, Train: 0.2707, Val: 0.3083
# Epoch: 489, Loss: 0.0736, Train: 0.2675, Val: 0.3007
# Epoch: 490, Loss: 0.0717, Train: 0.2668, Val: 0.3009
# Epoch: 491, Loss: 0.0713, Train: 0.2688, Val: 0.3063
# Epoch: 492, Loss: 0.0725, Train: 0.2698, Val: 0.3029
# Epoch: 493, Loss: 0.0729, Train: 0.2666, Val: 0.3050
# Epoch: 494, Loss: 0.0713, Train: 0.2673, Val: 0.3071
# Epoch: 495, Loss: 0.0717, Train: 0.2697, Val: 0.3050
# Epoch: 496, Loss: 0.0729, Train: 0.2674, Val: 0.3088
# Epoch: 497, Loss: 0.0718, Train: 0.2661, Val: 0.3050
# Epoch: 498, Loss: 0.0710, Train: 0.2671, Val: 0.3036
# Epoch: 499, Loss: 0.0715, Train: 0.2679, Val: 0.3073
# Epoch: 500, Loss: 0.0721, Train: 0.2683, Val: 0.3029
# Epoch: 501, Loss: 0.0721, Train: 0.2665, Val: 0.3053
# Epoch: 502, Loss: 0.0713, Train: 0.2660, Val: 0.3044
# Epoch: 503, Loss: 0.0710, Train: 0.2667, Val: 0.3044
# Epoch: 504, Loss: 0.0713, Train: 0.2671, Val: 0.3088
# Epoch: 505, Loss: 0.0717, Train: 0.2674, Val: 0.3048
# Epoch: 506, Loss: 0.0716, Train: 0.2663, Val: 0.3065
# Epoch: 507, Loss: 0.0711, Train: 0.2659, Val: 0.3045
# Epoch: 508, Loss: 0.0709, Train: 0.2664, Val: 0.3032
# Epoch: 509, Loss: 0.0711, Train: 0.2666, Val: 0.3050
# Epoch: 510, Loss: 0.0713, Train: 0.2666, Val: 0.3022
# Epoch: 511, Loss: 0.0712, Train: 0.2660, Val: 0.3032
# Epoch: 512, Loss: 0.0709, Train: 0.2659, Val: 0.3029
# Epoch: 513, Loss: 0.0709, Train: 0.2663, Val: 0.3020
# Epoch: 514, Loss: 0.0711, Train: 0.2663, Val: 0.3041
# Epoch: 515, Loss: 0.0711, Train: 0.2662, Val: 0.3024
# Epoch: 516, Loss: 0.0710, Train: 0.2658, Val: 0.3038
# Epoch: 517, Loss: 0.0709, Train: 0.2658, Val: 0.3039
# Epoch: 518, Loss: 0.0708, Train: 0.2660, Val: 0.3031
# Epoch: 519, Loss: 0.0709, Train: 0.2660, Val: 0.3045
# Epoch: 520, Loss: 0.0710, Train: 0.2661, Val: 0.3012
# Epoch: 521, Loss: 0.0710, Train: 0.2659, Val: 0.3014
# Epoch: 522, Loss: 0.0709, Train: 0.2658, Val: 0.2993
# Epoch: 523, Loss: 0.0708, Train: 0.2657, Val: 0.2995
# Epoch: 524, Loss: 0.0708, Train: 0.2657, Val: 0.3003
# Epoch: 525, Loss: 0.0708, Train: 0.2658, Val: 0.3007
# Epoch: 526, Loss: 0.0708, Train: 0.2658, Val: 0.3033
# Epoch: 527, Loss: 0.0708, Train: 0.2659, Val: 0.3027
# Epoch: 528, Loss: 0.0708, Train: 0.2657, Val: 0.3045
# Epoch: 529, Loss: 0.0708, Train: 0.2657, Val: 0.3033
# Epoch: 530, Loss: 0.0707, Train: 0.2656, Val: 0.3037
# Epoch: 531, Loss: 0.0707, Train: 0.2655, Val: 0.3030
# Epoch: 532, Loss: 0.0707, Train: 0.2656, Val: 0.3021
# Epoch: 533, Loss: 0.0707, Train: 0.2655, Val: 0.3023
# Epoch: 534, Loss: 0.0707, Train: 0.2656, Val: 0.3012
# Epoch: 535, Loss: 0.0707, Train: 0.2656, Val: 0.3023
# Epoch: 536, Loss: 0.0707, Train: 0.2656, Val: 0.3016
# Epoch: 537, Loss: 0.0707, Train: 0.2655, Val: 0.3032
# Epoch: 538, Loss: 0.0707, Train: 0.2656, Val: 0.3034
# Epoch: 539, Loss: 0.0707, Train: 0.2655, Val: 0.3053
# Epoch: 540, Loss: 0.0707, Train: 0.2655, Val: 0.3042
# Epoch: 541, Loss: 0.0706, Train: 0.2654, Val: 0.3042
# Epoch: 542, Loss: 0.0706, Train: 0.2654, Val: 0.3037
# Epoch: 543, Loss: 0.0706, Train: 0.2653, Val: 0.3052
# Epoch: 544, Loss: 0.0706, Train: 0.2654, Val: 0.3045
# Epoch: 545, Loss: 0.0706, Train: 0.2653, Val: 0.3041
# Epoch: 546, Loss: 0.0706, Train: 0.2653, Val: 0.3035
# Epoch: 547, Loss: 0.0706, Train: 0.2653, Val: 0.3047
# Epoch: 548, Loss: 0.0705, Train: 0.2653, Val: 0.3032
# Epoch: 549, Loss: 0.0705, Train: 0.2653, Val: 0.3041
# Epoch: 550, Loss: 0.0705, Train: 0.2653, Val: 0.3027
# Epoch: 551, Loss: 0.0705, Train: 0.2652, Val: 0.3038
# Epoch: 552, Loss: 0.0705, Train: 0.2653, Val: 0.3014
# Epoch: 553, Loss: 0.0706, Train: 0.2653, Val: 0.3025
# Epoch: 554, Loss: 0.0706, Train: 0.2656, Val: 0.3016
# Epoch: 555, Loss: 0.0707, Train: 0.2658, Val: 0.3059
# Epoch: 556, Loss: 0.0709, Train: 0.2667, Val: 0.3031
# Epoch: 557, Loss: 0.0713, Train: 0.2675, Val: 0.3094
# Epoch: 558, Loss: 0.0718, Train: 0.2704, Val: 0.3030
# Epoch: 559, Loss: 0.0732, Train: 0.2707, Val: 0.3115
# Epoch: 560, Loss: 0.0736, Train: 0.2727, Val: 0.3027
# Epoch: 561, Loss: 0.0744, Train: 0.2677, Val: 0.3048
# Epoch: 562, Loss: 0.0720, Train: 0.2654, Val: 0.3002
# Epoch: 563, Loss: 0.0706, Train: 0.2665, Val: 0.3007
# Epoch: 564, Loss: 0.0711, Train: 0.2676, Val: 0.3074
# Epoch: 565, Loss: 0.0719, Train: 0.2674, Val: 0.3049
# Epoch: 566, Loss: 0.0716, Train: 0.2653, Val: 0.3127
# Epoch: 567, Loss: 0.0706, Train: 0.2658, Val: 0.3192
# Epoch: 568, Loss: 0.0709, Train: 0.2679, Val: 0.3112
# Epoch: 569, Loss: 0.0719, Train: 0.2667, Val: 0.3184
# Epoch: 570, Loss: 0.0714, Train: 0.2657, Val: 0.3127
# Epoch: 571, Loss: 0.0708, Train: 0.2649, Val: 0.3190
# Epoch: 572, Loss: 0.0704, Train: 0.2654, Val: 0.3265
# Epoch: 573, Loss: 0.0707, Train: 0.2666, Val: 0.3345
# Epoch: 574, Loss: 0.0712, Train: 0.2668, Val: 0.3579
# Epoch: 575, Loss: 0.0722, Train: 0.2693, Val: 0.3352
# Epoch: 576, Loss: 0.0726, Train: 0.2680, Val: 0.3270
# Epoch: 577, Loss: 0.0721, Train: 0.2666, Val: 0.3100
# Epoch: 578, Loss: 0.0712, Train: 0.2650, Val: 0.3023
# Epoch: 579, Loss: 0.0704, Train: 0.2657, Val: 0.2987
# Epoch: 580, Loss: 0.0708, Train: 0.2673, Val: 0.2942
# Epoch: 581, Loss: 0.0715, Train: 0.2661, Val: 0.2951
# Epoch: 582, Loss: 0.0710, Train: 0.2651, Val: 0.2925
# Epoch: 583, Loss: 0.0704, Train: 0.2654, Val: 0.2925
# Epoch: 584, Loss: 0.0705, Train: 0.2660, Val: 0.2948
# Epoch: 585, Loss: 0.0710, Train: 0.2662, Val: 0.2930
# Epoch: 586, Loss: 0.0710, Train: 0.2651, Val: 0.2938
# Epoch: 587, Loss: 0.0705, Train: 0.2648, Val: 0.2932
# Epoch: 588, Loss: 0.0703, Train: 0.2654, Val: 0.2927
# Epoch: 589, Loss: 0.0706, Train: 0.2656, Val: 0.2945
# Epoch: 590, Loss: 0.0708, Train: 0.2658, Val: 0.2927
# Epoch: 591, Loss: 0.0708, Train: 0.2650, Val: 0.2936
# Epoch: 592, Loss: 0.0704, Train: 0.2648, Val: 0.2927
# Epoch: 593, Loss: 0.0703, Train: 0.2649, Val: 0.2924
# Epoch: 594, Loss: 0.0703, Train: 0.2651, Val: 0.2935
# Epoch: 595, Loss: 0.0705, Train: 0.2654, Val: 0.2923
# Epoch: 596, Loss: 0.0706, Train: 0.2650, Val: 0.2933
# Epoch: 597, Loss: 0.0704, Train: 0.2648, Val: 0.2921
# Epoch: 598, Loss: 0.0703, Train: 0.2647, Val: 0.2922
# Epoch: 599, Loss: 0.0702, Train: 0.2647, Val: 0.2926
# Epoch: 600, Loss: 0.0703, Train: 0.2650, Val: 0.2918
# Epoch: 601, Loss: 0.0704, Train: 0.2649, Val: 0.2927
# Epoch: 602, Loss: 0.0704, Train: 0.2648, Val: 0.2917
# Epoch: 603, Loss: 0.0703, Train: 0.2646, Val: 0.2920
# Epoch: 604, Loss: 0.0702, Train: 0.2646, Val: 0.2918
# Epoch: 605, Loss: 0.0702, Train: 0.2647, Val: 0.2915
# Epoch: 606, Loss: 0.0702, Train: 0.2647, Val: 0.2921
# Epoch: 607, Loss: 0.0703, Train: 0.2648, Val: 0.2913
# Epoch: 608, Loss: 0.0703, Train: 0.2647, Val: 0.2920
# Epoch: 609, Loss: 0.0702, Train: 0.2646, Val: 0.2912
# Epoch: 610, Loss: 0.0702, Train: 0.2645, Val: 0.2915
# Epoch: 611, Loss: 0.0701, Train: 0.2645, Val: 0.2913
# Epoch: 612, Loss: 0.0701, Train: 0.2645, Val: 0.2912
# Epoch: 613, Loss: 0.0701, Train: 0.2645, Val: 0.2915
# Epoch: 614, Loss: 0.0701, Train: 0.2646, Val: 0.2910
# Epoch: 615, Loss: 0.0702, Train: 0.2645, Val: 0.2916
# Epoch: 616, Loss: 0.0702, Train: 0.2646, Val: 0.2909
# Epoch: 617, Loss: 0.0702, Train: 0.2645, Val: 0.2915
# Epoch: 618, Loss: 0.0702, Train: 0.2646, Val: 0.2908
# Epoch: 619, Loss: 0.0701, Train: 0.2645, Val: 0.2913
# Epoch: 620, Loss: 0.0701, Train: 0.2645, Val: 0.2907
# Epoch: 621, Loss: 0.0701, Train: 0.2644, Val: 0.2911
# Epoch: 622, Loss: 0.0701, Train: 0.2645, Val: 0.2906
# Epoch: 623, Loss: 0.0701, Train: 0.2644, Val: 0.2910
# Epoch: 624, Loss: 0.0701, Train: 0.2645, Val: 0.2905
# Epoch: 625, Loss: 0.0701, Train: 0.2644, Val: 0.2911
# Epoch: 626, Loss: 0.0701, Train: 0.2647, Val: 0.2903
# Epoch: 627, Loss: 0.0702, Train: 0.2650, Val: 0.2919
# Epoch: 628, Loss: 0.0705, Train: 0.2666, Val: 0.2909
# Epoch: 629, Loss: 0.0711, Train: 0.2684, Val: 0.2955
# Epoch: 630, Loss: 0.0723, Train: 0.2733, Val: 0.2949
# Epoch: 631, Loss: 0.0747, Train: 0.2709, Val: 0.2980
# Epoch: 632, Loss: 0.0737, Train: 0.2690, Val: 0.2924
# Epoch: 633, Loss: 0.0724, Train: 0.2646, Val: 0.2913
# Epoch: 634, Loss: 0.0702, Train: 0.2665, Val: 0.2938
# Epoch: 635, Loss: 0.0713, Train: 0.2697, Val: 0.2930
# Epoch: 636, Loss: 0.0728, Train: 0.2654, Val: 0.2926
# Epoch: 637, Loss: 0.0706, Train: 0.2654, Val: 0.2927
# Epoch: 638, Loss: 0.0707, Train: 0.2685, Val: 0.2924
# Epoch: 639, Loss: 0.0722, Train: 0.2656, Val: 0.2931
# Epoch: 640, Loss: 0.0708, Train: 0.2643, Val: 0.2912
# Epoch: 641, Loss: 0.0700, Train: 0.2660, Val: 0.2912
# Epoch: 642, Loss: 0.0709, Train: 0.2664, Val: 0.2941
# Epoch: 643, Loss: 0.0713, Train: 0.2661, Val: 0.2912
# Epoch: 644, Loss: 0.0709, Train: 0.2643, Val: 0.2915
# Epoch: 645, Loss: 0.0701, Train: 0.2643, Val: 0.2916
# Epoch: 646, Loss: 0.0701, Train: 0.2657, Val: 0.2911
# Epoch: 647, Loss: 0.0707, Train: 0.2656, Val: 0.2933
# Epoch: 648, Loss: 0.0708, Train: 0.2652, Val: 0.2909
# Epoch: 649, Loss: 0.0705, Train: 0.2642, Val: 0.2913
# Epoch: 650, Loss: 0.0700, Train: 0.2643, Val: 0.2917
# Epoch: 651, Loss: 0.0701, Train: 0.2652, Val: 0.2909
# Epoch: 652, Loss: 0.0705, Train: 0.2648, Val: 0.2925
# Epoch: 653, Loss: 0.0703, Train: 0.2644, Val: 0.2909
# Epoch: 654, Loss: 0.0700, Train: 0.2642, Val: 0.2910
# Epoch: 655, Loss: 0.0699, Train: 0.2645, Val: 0.2920
# Epoch: 656, Loss: 0.0701, Train: 0.2649, Val: 0.2909
# Epoch: 657, Loss: 0.0703, Train: 0.2644, Val: 0.2918
# Epoch: 658, Loss: 0.0701, Train: 0.2641, Val: 0.2909
# Epoch: 659, Loss: 0.0699, Train: 0.2641, Val: 0.2908
# Epoch: 660, Loss: 0.0699, Train: 0.2643, Val: 0.2917
# Epoch: 661, Loss: 0.0700, Train: 0.2646, Val: 0.2906
# Epoch: 662, Loss: 0.0701, Train: 0.2642, Val: 0.2915
# Epoch: 663, Loss: 0.0700, Train: 0.2641, Val: 0.2905
# Epoch: 664, Loss: 0.0699, Train: 0.2640, Val: 0.2906
# Epoch: 665, Loss: 0.0698, Train: 0.2640, Val: 0.2910
# Epoch: 666, Loss: 0.0699, Train: 0.2643, Val: 0.2903
# Epoch: 667, Loss: 0.0700, Train: 0.2642, Val: 0.2912
# Epoch: 668, Loss: 0.0700, Train: 0.2641, Val: 0.2903
# Epoch: 669, Loss: 0.0699, Train: 0.2639, Val: 0.2906
# Epoch: 670, Loss: 0.0698, Train: 0.2639, Val: 0.2904
# Epoch: 671, Loss: 0.0698, Train: 0.2640, Val: 0.2902
# Epoch: 672, Loss: 0.0698, Train: 0.2640, Val: 0.2907
# Epoch: 673, Loss: 0.0699, Train: 0.2641, Val: 0.2901
# Epoch: 674, Loss: 0.0699, Train: 0.2639, Val: 0.2906
# Epoch: 675, Loss: 0.0698, Train: 0.2639, Val: 0.2900
# Epoch: 676, Loss: 0.0698, Train: 0.2638, Val: 0.2902
# Epoch: 677, Loss: 0.0698, Train: 0.2638, Val: 0.2902
# Epoch: 678, Loss: 0.0698, Train: 0.2639, Val: 0.2899
# Epoch: 679, Loss: 0.0698, Train: 0.2639, Val: 0.2903
# Epoch: 680, Loss: 0.0698, Train: 0.2639, Val: 0.2898
# Epoch: 681, Loss: 0.0698, Train: 0.2638, Val: 0.2902
# Epoch: 682, Loss: 0.0698, Train: 0.2639, Val: 0.2897
# Epoch: 683, Loss: 0.0698, Train: 0.2638, Val: 0.2900
# Epoch: 684, Loss: 0.0697, Train: 0.2638, Val: 0.2897
# Epoch: 685, Loss: 0.0697, Train: 0.2637, Val: 0.2898
# Epoch: 686, Loss: 0.0697, Train: 0.2637, Val: 0.2898
# Epoch: 687, Loss: 0.0697, Train: 0.2638, Val: 0.2896
# Epoch: 688, Loss: 0.0697, Train: 0.2637, Val: 0.2899
# Epoch: 689, Loss: 0.0697, Train: 0.2638, Val: 0.2895
# Epoch: 690, Loss: 0.0697, Train: 0.2637, Val: 0.2899
# Epoch: 691, Loss: 0.0697, Train: 0.2638, Val: 0.2894
# Epoch: 692, Loss: 0.0697, Train: 0.2637, Val: 0.2898
# Epoch: 693, Loss: 0.0697, Train: 0.2638, Val: 0.2894
# Epoch: 694, Loss: 0.0697, Train: 0.2637, Val: 0.2897
# Epoch: 695, Loss: 0.0697, Train: 0.2637, Val: 0.2893
# Epoch: 696, Loss: 0.0697, Train: 0.2637, Val: 0.2896
# Epoch: 697, Loss: 0.0697, Train: 0.2637, Val: 0.2893
# Epoch: 698, Loss: 0.0697, Train: 0.2636, Val: 0.2896
# Epoch: 699, Loss: 0.0697, Train: 0.2637, Val: 0.2892
# Epoch: 700, Loss: 0.0697, Train: 0.2636, Val: 0.2896
# Epoch: 701, Loss: 0.0697, Train: 0.2637, Val: 0.2891
# Epoch: 702, Loss: 0.0697, Train: 0.2636, Val: 0.2896
# Epoch: 703, Loss: 0.0697, Train: 0.2638, Val: 0.2890
# Epoch: 704, Loss: 0.0697, Train: 0.2638, Val: 0.2898
# Epoch: 705, Loss: 0.0698, Train: 0.2641, Val: 0.2890
# Epoch: 706, Loss: 0.0699, Train: 0.2642, Val: 0.2904
# Epoch: 707, Loss: 0.0700, Train: 0.2650, Val: 0.2893
# Epoch: 708, Loss: 0.0703, Train: 0.2654, Val: 0.2917
# Epoch: 709, Loss: 0.0707, Train: 0.2671, Val: 0.2903
# Epoch: 710, Loss: 0.0714, Train: 0.2673, Val: 0.2938
# Epoch: 711, Loss: 0.0717, Train: 0.2690, Val: 0.2914
# Epoch: 712, Loss: 0.0724, Train: 0.2665, Val: 0.2931
# Epoch: 713, Loss: 0.0713, Train: 0.2650, Val: 0.2895
# Epoch: 714, Loss: 0.0703, Train: 0.2637, Val: 0.2896
# Epoch: 715, Loss: 0.0697, Train: 0.2642, Val: 0.2906
# Epoch: 716, Loss: 0.0700, Train: 0.2657, Val: 0.2899
# Epoch: 717, Loss: 0.0707, Train: 0.2651, Val: 0.2917
# Epoch: 718, Loss: 0.0705, Train: 0.2644, Val: 0.2893
# Epoch: 719, Loss: 0.0700, Train: 0.2635, Val: 0.2895
# Epoch: 720, Loss: 0.0696, Train: 0.2636, Val: 0.2897
# Epoch: 721, Loss: 0.0697, Train: 0.2645, Val: 0.2892
# Epoch: 722, Loss: 0.0701, Train: 0.2649, Val: 0.2914
# Epoch: 723, Loss: 0.0704, Train: 0.2658, Val: 0.2897
# Epoch: 724, Loss: 0.0708, Train: 0.2650, Val: 0.2915
# Epoch: 725, Loss: 0.0705, Train: 0.2649, Val: 0.2892
# Epoch: 726, Loss: 0.0703, Train: 0.2639, Val: 0.2901
# Epoch: 727, Loss: 0.0698, Train: 0.2635, Val: 0.2889
# Epoch: 728, Loss: 0.0696, Train: 0.2634, Val: 0.2890
# Epoch: 729, Loss: 0.0695, Train: 0.2637, Val: 0.2899
# Epoch: 730, Loss: 0.0697, Train: 0.2642, Val: 0.2890
# Epoch: 731, Loss: 0.0699, Train: 0.2640, Val: 0.2904
# Epoch: 732, Loss: 0.0699, Train: 0.2639, Val: 0.2890
# Epoch: 733, Loss: 0.0698, Train: 0.2635, Val: 0.2896
# Epoch: 734, Loss: 0.0696, Train: 0.2633, Val: 0.2891
# Epoch: 735, Loss: 0.0695, Train: 0.2634, Val: 0.2890
# Epoch: 736, Loss: 0.0695, Train: 0.2635, Val: 0.2896
# Epoch: 737, Loss: 0.0696, Train: 0.2638, Val: 0.2889
# Epoch: 738, Loss: 0.0697, Train: 0.2638, Val: 0.2901
# Epoch: 739, Loss: 0.0698, Train: 0.2640, Val: 0.2889
# Epoch: 740, Loss: 0.0698, Train: 0.2638, Val: 0.2901
# Epoch: 741, Loss: 0.0698, Train: 0.2639, Val: 0.2888
# Epoch: 742, Loss: 0.0698, Train: 0.2636, Val: 0.2898
# Epoch: 743, Loss: 0.0697, Train: 0.2636, Val: 0.2887
# Epoch: 744, Loss: 0.0696, Train: 0.2634, Val: 0.2893
# Epoch: 745, Loss: 0.0695, Train: 0.2633, Val: 0.2887
# Epoch: 746, Loss: 0.0695, Train: 0.2632, Val: 0.2889
# Epoch: 747, Loss: 0.0694, Train: 0.2632, Val: 0.2888
# Epoch: 748, Loss: 0.0694, Train: 0.2632, Val: 0.2886
# Epoch: 749, Loss: 0.0694, Train: 0.2632, Val: 0.2890
# Epoch: 750, Loss: 0.0695, Train: 0.2633, Val: 0.2885
# Epoch: 751, Loss: 0.0695, Train: 0.2633, Val: 0.2891
# Epoch: 752, Loss: 0.0695, Train: 0.2635, Val: 0.2884
# Epoch: 753, Loss: 0.0696, Train: 0.2634, Val: 0.2893
# Epoch: 754, Loss: 0.0696, Train: 0.2638, Val: 0.2883
# Epoch: 755, Loss: 0.0697, Train: 0.2638, Val: 0.2896
# Epoch: 756, Loss: 0.0698, Train: 0.2643, Val: 0.2885
# Epoch: 757, Loss: 0.0700, Train: 0.2644, Val: 0.2904
# Epoch: 758, Loss: 0.0701, Train: 0.2654, Val: 0.2889
# Epoch: 759, Loss: 0.0705, Train: 0.2654, Val: 0.2914
# Epoch: 760, Loss: 0.0707, Train: 0.2665, Val: 0.2895
# Epoch: 761, Loss: 0.0711, Train: 0.2655, Val: 0.2916
# Epoch: 762, Loss: 0.0707, Train: 0.2653, Val: 0.2890
# Epoch: 763, Loss: 0.0705, Train: 0.2638, Val: 0.2898
# Epoch: 764, Loss: 0.0698, Train: 0.2632, Val: 0.2884
# Epoch: 765, Loss: 0.0694, Train: 0.2633, Val: 0.2884
# Epoch: 766, Loss: 0.0695, Train: 0.2637, Val: 0.2897
# Epoch: 767, Loss: 0.0697, Train: 0.2645, Val: 0.2886
# Epoch: 768, Loss: 0.0701, Train: 0.2642, Val: 0.2902
# Epoch: 769, Loss: 0.0700, Train: 0.2643, Val: 0.2884
# Epoch: 770, Loss: 0.0700, Train: 0.2635, Val: 0.2894
# Epoch: 771, Loss: 0.0697, Train: 0.2633, Val: 0.2881
# Epoch: 772, Loss: 0.0695, Train: 0.2630, Val: 0.2884
# Epoch: 773, Loss: 0.0694, Train: 0.2630, Val: 0.2882
# Epoch: 774, Loss: 0.0693, Train: 0.2631, Val: 0.2879
# Epoch: 775, Loss: 0.0694, Train: 0.2632, Val: 0.2887
# Epoch: 776, Loss: 0.0695, Train: 0.2636, Val: 0.2879
# Epoch: 777, Loss: 0.0696, Train: 0.2637, Val: 0.2893
# Epoch: 778, Loss: 0.0698, Train: 0.2642, Val: 0.2881
# Epoch: 779, Loss: 0.0699, Train: 0.2641, Val: 0.2898
# Epoch: 780, Loss: 0.0700, Train: 0.2646, Val: 0.2883
# Epoch: 781, Loss: 0.0701, Train: 0.2641, Val: 0.2899
# Epoch: 782, Loss: 0.0700, Train: 0.2642, Val: 0.2881
# Epoch: 783, Loss: 0.0699, Train: 0.2635, Val: 0.2892
# Epoch: 784, Loss: 0.0696, Train: 0.2633, Val: 0.2879
# Epoch: 785, Loss: 0.0695, Train: 0.2630, Val: 0.2884
# Epoch: 786, Loss: 0.0693, Train: 0.2629, Val: 0.2882
# Epoch: 787, Loss: 0.0693, Train: 0.2630, Val: 0.2879
# Epoch: 788, Loss: 0.0693, Train: 0.2631, Val: 0.2887
# Epoch: 789, Loss: 0.0694, Train: 0.2635, Val: 0.2879
# Epoch: 790, Loss: 0.0695, Train: 0.2635, Val: 0.2892
# Epoch: 791, Loss: 0.0697, Train: 0.2641, Val: 0.2881
# Epoch: 792, Loss: 0.0699, Train: 0.2641, Val: 0.2898
# Epoch: 793, Loss: 0.0700, Train: 0.2649, Val: 0.2884
# Epoch: 794, Loss: 0.0703, Train: 0.2647, Val: 0.2906
# Epoch: 795, Loss: 0.0703, Train: 0.2656, Val: 0.2887
# Epoch: 796, Loss: 0.0706, Train: 0.2647, Val: 0.2906
# Epoch: 797, Loss: 0.0703, Train: 0.2646, Val: 0.2883
# Epoch: 798, Loss: 0.0701, Train: 0.2635, Val: 0.2892
# Epoch: 799, Loss: 0.0696, Train: 0.2630, Val: 0.2879
# Epoch: 800, Loss: 0.0693, Train: 0.2629, Val: 0.2879
# Epoch: 801, Loss: 0.0693, Train: 0.2632, Val: 0.2888
# Epoch: 802, Loss: 0.0695, Train: 0.2638, Val: 0.2879
# Epoch: 803, Loss: 0.0697, Train: 0.2637, Val: 0.2894
# Epoch: 804, Loss: 0.0698, Train: 0.2640, Val: 0.2879
# Epoch: 805, Loss: 0.0698, Train: 0.2635, Val: 0.2891
# Epoch: 806, Loss: 0.0697, Train: 0.2634, Val: 0.2876
# Epoch: 807, Loss: 0.0695, Train: 0.2630, Val: 0.2883
# Epoch: 808, Loss: 0.0694, Train: 0.2629, Val: 0.2875
# Epoch: 809, Loss: 0.0693, Train: 0.2627, Val: 0.2878
# Epoch: 810, Loss: 0.0692, Train: 0.2627, Val: 0.2876
# Epoch: 811, Loss: 0.0692, Train: 0.2628, Val: 0.2875
# Epoch: 812, Loss: 0.0692, Train: 0.2628, Val: 0.2878
# Epoch: 813, Loss: 0.0692, Train: 0.2629, Val: 0.2874
# Epoch: 814, Loss: 0.0693, Train: 0.2629, Val: 0.2882
# Epoch: 815, Loss: 0.0693, Train: 0.2632, Val: 0.2874
# Epoch: 816, Loss: 0.0694, Train: 0.2632, Val: 0.2886
# Epoch: 817, Loss: 0.0695, Train: 0.2637, Val: 0.2875
# Epoch: 818, Loss: 0.0697, Train: 0.2637, Val: 0.2892
# Epoch: 819, Loss: 0.0698, Train: 0.2644, Val: 0.2878
# Epoch: 820, Loss: 0.0700, Train: 0.2642, Val: 0.2898
# Epoch: 821, Loss: 0.0700, Train: 0.2648, Val: 0.2881
# Epoch: 822, Loss: 0.0702, Train: 0.2642, Val: 0.2899
# Epoch: 823, Loss: 0.0701, Train: 0.2643, Val: 0.2879
# Epoch: 824, Loss: 0.0700, Train: 0.2635, Val: 0.2890
# Epoch: 825, Loss: 0.0696, Train: 0.2631, Val: 0.2875
# Epoch: 826, Loss: 0.0694, Train: 0.2627, Val: 0.2879
# Epoch: 827, Loss: 0.0692, Train: 0.2626, Val: 0.2877
# Epoch: 828, Loss: 0.0691, Train: 0.2628, Val: 0.2874
# Epoch: 829, Loss: 0.0692, Train: 0.2630, Val: 0.2883
# Epoch: 830, Loss: 0.0694, Train: 0.2636, Val: 0.2874
# Epoch: 831, Loss: 0.0696, Train: 0.2636, Val: 0.2891
# Epoch: 832, Loss: 0.0698, Train: 0.2645, Val: 0.2877
# Epoch: 833, Loss: 0.0701, Train: 0.2644, Val: 0.2898
# Epoch: 834, Loss: 0.0702, Train: 0.2654, Val: 0.2881
# Epoch: 835, Loss: 0.0705, Train: 0.2647, Val: 0.2902
# Epoch: 836, Loss: 0.0703, Train: 0.2649, Val: 0.2879
# Epoch: 837, Loss: 0.0703, Train: 0.2636, Val: 0.2890
# Epoch: 838, Loss: 0.0697, Train: 0.2630, Val: 0.2873
# Epoch: 839, Loss: 0.0693, Train: 0.2626, Val: 0.2875
# Epoch: 840, Loss: 0.0691, Train: 0.2627, Val: 0.2879
# Epoch: 841, Loss: 0.0692, Train: 0.2634, Val: 0.2873
# Epoch: 842, Loss: 0.0695, Train: 0.2634, Val: 0.2889
# Epoch: 843, Loss: 0.0696, Train: 0.2638, Val: 0.2874
# Epoch: 844, Loss: 0.0697, Train: 0.2633, Val: 0.2886
# Epoch: 845, Loss: 0.0695, Train: 0.2632, Val: 0.2871
# Epoch: 846, Loss: 0.0694, Train: 0.2627, Val: 0.2878
# Epoch: 847, Loss: 0.0692, Train: 0.2626, Val: 0.2870
# Epoch: 848, Loss: 0.0691, Train: 0.2625, Val: 0.2872
# Epoch: 849, Loss: 0.0691, Train: 0.2625, Val: 0.2872
# Epoch: 850, Loss: 0.0691, Train: 0.2626, Val: 0.2869
# Epoch: 851, Loss: 0.0691, Train: 0.2626, Val: 0.2875
# Epoch: 852, Loss: 0.0692, Train: 0.2629, Val: 0.2869
# Epoch: 853, Loss: 0.0692, Train: 0.2629, Val: 0.2880
# Epoch: 854, Loss: 0.0693, Train: 0.2633, Val: 0.2870
# Epoch: 855, Loss: 0.0694, Train: 0.2632, Val: 0.2884
# Epoch: 856, Loss: 0.0695, Train: 0.2637, Val: 0.2872
# Epoch: 857, Loss: 0.0697, Train: 0.2635, Val: 0.2888
# Epoch: 858, Loss: 0.0697, Train: 0.2639, Val: 0.2873
# Epoch: 859, Loss: 0.0698, Train: 0.2635, Val: 0.2888
# Epoch: 860, Loss: 0.0697, Train: 0.2637, Val: 0.2872
# Epoch: 861, Loss: 0.0696, Train: 0.2631, Val: 0.2884
# Epoch: 862, Loss: 0.0695, Train: 0.2630, Val: 0.2870
# Epoch: 863, Loss: 0.0693, Train: 0.2626, Val: 0.2877
# Epoch: 864, Loss: 0.0692, Train: 0.2625, Val: 0.2870
# Epoch: 865, Loss: 0.0691, Train: 0.2624, Val: 0.2871
# Epoch: 866, Loss: 0.0690, Train: 0.2624, Val: 0.2871
# Epoch: 867, Loss: 0.0690, Train: 0.2625, Val: 0.2868
# Epoch: 868, Loss: 0.0691, Train: 0.2625, Val: 0.2874
# Epoch: 869, Loss: 0.0691, Train: 0.2629, Val: 0.2867
# Epoch: 870, Loss: 0.0692, Train: 0.2630, Val: 0.2879
# Epoch: 871, Loss: 0.0694, Train: 0.2637, Val: 0.2870
# Epoch: 872, Loss: 0.0697, Train: 0.2641, Val: 0.2891
# Epoch: 873, Loss: 0.0700, Train: 0.2657, Val: 0.2880
# Epoch: 874, Loss: 0.0707, Train: 0.2659, Val: 0.2910
# Epoch: 875, Loss: 0.0710, Train: 0.2677, Val: 0.2892
# Epoch: 876, Loss: 0.0717, Train: 0.2657, Val: 0.2910
# Epoch: 877, Loss: 0.0709, Train: 0.2646, Val: 0.2876
# Epoch: 878, Loss: 0.0701, Train: 0.2627, Val: 0.2878
# Epoch: 879, Loss: 0.0692, Train: 0.2627, Val: 0.2878
# Epoch: 880, Loss: 0.0692, Train: 0.2640, Val: 0.2875
# Epoch: 881, Loss: 0.0698, Train: 0.2641, Val: 0.2896
# Epoch: 882, Loss: 0.0700, Train: 0.2640, Val: 0.2874
# Epoch: 883, Loss: 0.0698, Train: 0.2627, Val: 0.2879
# Epoch: 884, Loss: 0.0692, Train: 0.2623, Val: 0.2869
# Epoch: 885, Loss: 0.0690, Train: 0.2626, Val: 0.2867
# Epoch: 886, Loss: 0.0691, Train: 0.2631, Val: 0.2882
# Epoch: 887, Loss: 0.0695, Train: 0.2642, Val: 0.2872
# Epoch: 888, Loss: 0.0699, Train: 0.2640, Val: 0.2891
# Epoch: 889, Loss: 0.0700, Train: 0.2645, Val: 0.2873
# Epoch: 890, Loss: 0.0701, Train: 0.2634, Val: 0.2885
# Epoch: 891, Loss: 0.0697, Train: 0.2630, Val: 0.2866
# Epoch: 892, Loss: 0.0693, Train: 0.2623, Val: 0.2870
# Epoch: 893, Loss: 0.0690, Train: 0.2623, Val: 0.2869
# Epoch: 894, Loss: 0.0690, Train: 0.2627, Val: 0.2866
# Epoch: 895, Loss: 0.0691, Train: 0.2628, Val: 0.2879
# Epoch: 896, Loss: 0.0693, Train: 0.2632, Val: 0.2867
# Epoch: 897, Loss: 0.0694, Train: 0.2627, Val: 0.2877
# Epoch: 898, Loss: 0.0692, Train: 0.2626, Val: 0.2865
# Epoch: 899, Loss: 0.0691, Train: 0.2622, Val: 0.2869
# Epoch: 900, Loss: 0.0690, Train: 0.2622, Val: 0.2867
# Epoch: 901, Loss: 0.0689, Train: 0.2623, Val: 0.2865
# Epoch: 902, Loss: 0.0690, Train: 0.2624, Val: 0.2872
# Epoch: 903, Loss: 0.0691, Train: 0.2628, Val: 0.2865
# Epoch: 904, Loss: 0.0692, Train: 0.2627, Val: 0.2876
# Epoch: 905, Loss: 0.0692, Train: 0.2630, Val: 0.2865
# ...
# Epoch: 2705, Loss: 0.0676, Train: 0.2603, Val: 0.2825
# Epoch: 2706, Loss: 0.0678, Train: 0.2605, Val: 0.2854
# Epoch: 2707, Loss: 0.0680, Train: 0.2611, Val: 0.2825
# Epoch: 2708, Loss: 0.0682, Train: 0.2608, Val: 0.2859
# Epoch: 2709, Loss: 0.0681, Train: 0.2608, Val: 0.2826
# Epoch: 2710, Loss: 0.0681, Train: 0.2601, Val: 0.2850
# Epoch: 2711, Loss: 0.0678, Train: 0.2597, Val: 0.2829
# Epoch: 2712, Loss: 0.0675, Train: 0.2595, Val: 0.2834
# Epoch: 2713, Loss: 0.0674, Train: 0.2595, Val: 0.2840
# Epoch: 2714, Loss: 0.0675, Train: 0.2600, Val: 0.2827
# Epoch: 2715, Loss: 0.0677, Train: 0.2601, Val: 0.2850
# Epoch: 2716, Loss: 0.0678, Train: 0.2605, Val: 0.2826
# Epoch: 2717, Loss: 0.0679, Train: 0.2604, Val: 0.2854
# Epoch: 2718, Loss: 0.0679, Train: 0.2604, Val: 0.2826
# Epoch: 2719, Loss: 0.0679, Train: 0.2600, Val: 0.2848
# Epoch: 2720, Loss: 0.0677, Train: 0.2597, Val: 0.2828
# Epoch: 2721, Loss: 0.0675, Train: 0.2595, Val: 0.2836
# Epoch: 2722, Loss: 0.0674, Train: 0.2594, Val: 0.2836
# Epoch: 2723, Loss: 0.0674, Train: 0.2596, Val: 0.2829
# Epoch: 2724, Loss: 0.0675, Train: 0.2597, Val: 0.2845
# Epoch: 2725, Loss: 0.0676, Train: 0.2601, Val: 0.2828
# Epoch: 2726, Loss: 0.0677, Train: 0.2601, Val: 0.2852
# Epoch: 2727, Loss: 0.0678, Train: 0.2603, Val: 0.2828
# Epoch: 2728, Loss: 0.0678, Train: 0.2600, Val: 0.2853
# Epoch: 2729, Loss: 0.0677, Train: 0.2600, Val: 0.2830
# Epoch: 2730, Loss: 0.0676, Train: 0.2596, Val: 0.2845
# Epoch: 2731, Loss: 0.0675, Train: 0.2595, Val: 0.2834
# Epoch: 2732, Loss: 0.0674, Train: 0.2594, Val: 0.2836
# Epoch: 2733, Loss: 0.0674, Train: 0.2594, Val: 0.2840
# Epoch: 2734, Loss: 0.0674, Train: 0.2596, Val: 0.2831
# Epoch: 2735, Loss: 0.0675, Train: 0.2597, Val: 0.2847
# Epoch: 2736, Loss: 0.0676, Train: 0.2600, Val: 0.2830
# Epoch: 2737, Loss: 0.0676, Train: 0.2599, Val: 0.2852
# Epoch: 2738, Loss: 0.0677, Train: 0.2601, Val: 0.2831
# Epoch: 2739, Loss: 0.0677, Train: 0.2599, Val: 0.2853
# Epoch: 2740, Loss: 0.0677, Train: 0.2599, Val: 0.2832
# Epoch: 2741, Loss: 0.0676, Train: 0.2596, Val: 0.2847
# Epoch: 2742, Loss: 0.0675, Train: 0.2595, Val: 0.2835
# Epoch: 2743, Loss: 0.0674, Train: 0.2594, Val: 0.2840
# Epoch: 2744, Loss: 0.0674, Train: 0.2594, Val: 0.2839
# Epoch: 2745, Loss: 0.0674, Train: 0.2595, Val: 0.2835
# Epoch: 2746, Loss: 0.0674, Train: 0.2595, Val: 0.2844
# Epoch: 2747, Loss: 0.0674, Train: 0.2597, Val: 0.2833
# Epoch: 2748, Loss: 0.0675, Train: 0.2597, Val: 0.2849
# Epoch: 2749, Loss: 0.0675, Train: 0.2598, Val: 0.2833
# Epoch: 2750, Loss: 0.0676, Train: 0.2597, Val: 0.2850
# Epoch: 2751, Loss: 0.0676, Train: 0.2598, Val: 0.2833
# Epoch: 2752, Loss: 0.0675, Train: 0.2596, Val: 0.2849
# Epoch: 2753, Loss: 0.0675, Train: 0.2596, Val: 0.2835
# Epoch: 2754, Loss: 0.0675, Train: 0.2595, Val: 0.2846
# Epoch: 2755, Loss: 0.0674, Train: 0.2595, Val: 0.2836
# Epoch: 2756, Loss: 0.0674, Train: 0.2594, Val: 0.2844
# Epoch: 2757, Loss: 0.0674, Train: 0.2594, Val: 0.2838
# Epoch: 2758, Loss: 0.0674, Train: 0.2594, Val: 0.2841
# Epoch: 2759, Loss: 0.0674, Train: 0.2594, Val: 0.2840
# Epoch: 2760, Loss: 0.0674, Train: 0.2594, Val: 0.2840
# Epoch: 2761, Loss: 0.0674, Train: 0.2594, Val: 0.2842
# Epoch: 2762, Loss: 0.0674, Train: 0.2594, Val: 0.2839
# Epoch: 2763, Loss: 0.0674, Train: 0.2594, Val: 0.2845
# Epoch: 2764, Loss: 0.0674, Train: 0.2595, Val: 0.2838
# Epoch: 2765, Loss: 0.0674, Train: 0.2594, Val: 0.2847
# Epoch: 2766, Loss: 0.0674, Train: 0.2595, Val: 0.2838
# Epoch: 2767, Loss: 0.0674, Train: 0.2595, Val: 0.2850
# Epoch: 2768, Loss: 0.0674, Train: 0.2597, Val: 0.2838
# Epoch: 2769, Loss: 0.0675, Train: 0.2596, Val: 0.2854
# Epoch: 2770, Loss: 0.0675, Train: 0.2598, Val: 0.2838
# Epoch: 2771, Loss: 0.0676, Train: 0.2598, Val: 0.2858
# Epoch: 2772, Loss: 0.0676, Train: 0.2600, Val: 0.2838
# Epoch: 2773, Loss: 0.0677, Train: 0.2600, Val: 0.2863
# Epoch: 2774, Loss: 0.0677, Train: 0.2604, Val: 0.2838
# Epoch: 2775, Loss: 0.0678, Train: 0.2603, Val: 0.2868
# Epoch: 2776, Loss: 0.0679, Train: 0.2606, Val: 0.2840
# Epoch: 2777, Loss: 0.0680, Train: 0.2604, Val: 0.2871
# Epoch: 2778, Loss: 0.0679, Train: 0.2605, Val: 0.2841
# Epoch: 2779, Loss: 0.0679, Train: 0.2601, Val: 0.2867
# Epoch: 2780, Loss: 0.0677, Train: 0.2599, Val: 0.2842
# Epoch: 2781, Loss: 0.0676, Train: 0.2595, Val: 0.2857
# Epoch: 2782, Loss: 0.0675, Train: 0.2594, Val: 0.2845
# Epoch: 2783, Loss: 0.0674, Train: 0.2593, Val: 0.2848
# Epoch: 2784, Loss: 0.0673, Train: 0.2594, Val: 0.2850
# Epoch: 2785, Loss: 0.0674, Train: 0.2595, Val: 0.2843
# Epoch: 2786, Loss: 0.0674, Train: 0.2596, Val: 0.2857
# Epoch: 2787, Loss: 0.0675, Train: 0.2599, Val: 0.2841
# Epoch: 2788, Loss: 0.0676, Train: 0.2599, Val: 0.2864
# Epoch: 2789, Loss: 0.0677, Train: 0.2602, Val: 0.2841
# Epoch: 2790, Loss: 0.0678, Train: 0.2601, Val: 0.2869
# Epoch: 2791, Loss: 0.0678, Train: 0.2603, Val: 0.2842
# Epoch: 2792, Loss: 0.0678, Train: 0.2601, Val: 0.2869
# Epoch: 2793, Loss: 0.0677, Train: 0.2601, Val: 0.2843
# Epoch: 2794, Loss: 0.0677, Train: 0.2597, Val: 0.2863
# Epoch: 2795, Loss: 0.0676, Train: 0.2596, Val: 0.2845
# Epoch: 2796, Loss: 0.0675, Train: 0.2594, Val: 0.2855
# Epoch: 2797, Loss: 0.0674, Train: 0.2593, Val: 0.2849
# Epoch: 2798, Loss: 0.0673, Train: 0.2593, Val: 0.2849
# Epoch: 2799, Loss: 0.0673, Train: 0.2594, Val: 0.2853
# Epoch: 2800, Loss: 0.0674, Train: 0.2595, Val: 0.2845
# Epoch: 2801, Loss: 0.0674, Train: 0.2595, Val: 0.2858
# Epoch: 2802, Loss: 0.0674, Train: 0.2597, Val: 0.2844
# Epoch: 2803, Loss: 0.0675, Train: 0.2598, Val: 0.2864
# Epoch: 2804, Loss: 0.0676, Train: 0.2601, Val: 0.2844
# Epoch: 2805, Loss: 0.0677, Train: 0.2600, Val: 0.2870
# Epoch: 2806, Loss: 0.0677, Train: 0.2603, Val: 0.2845
# Epoch: 2807, Loss: 0.0678, Train: 0.2601, Val: 0.2873
# Epoch: 2808, Loss: 0.0678, Train: 0.2603, Val: 0.2846
# Epoch: 2809, Loss: 0.0678, Train: 0.2600, Val: 0.2872
# Epoch: 2810, Loss: 0.0677, Train: 0.2599, Val: 0.2847
# Epoch: 2811, Loss: 0.0676, Train: 0.2596, Val: 0.2865
# Epoch: 2812, Loss: 0.0675, Train: 0.2595, Val: 0.2849
# Epoch: 2813, Loss: 0.0674, Train: 0.2593, Val: 0.2857
# Epoch: 2814, Loss: 0.0673, Train: 0.2593, Val: 0.2852
# Epoch: 2815, Loss: 0.0673, Train: 0.2593, Val: 0.2851
# Epoch: 2816, Loss: 0.0673, Train: 0.2594, Val: 0.2857
# Epoch: 2817, Loss: 0.0673, Train: 0.2595, Val: 0.2848
# Epoch: 2818, Loss: 0.0674, Train: 0.2595, Val: 0.2862
# Epoch: 2819, Loss: 0.0674, Train: 0.2598, Val: 0.2847
# Epoch: 2820, Loss: 0.0675, Train: 0.2598, Val: 0.2868
# Epoch: 2821, Loss: 0.0676, Train: 0.2600, Val: 0.2847
# Epoch: 2822, Loss: 0.0677, Train: 0.2600, Val: 0.2873
# Epoch: 2823, Loss: 0.0677, Train: 0.2602, Val: 0.2848
# Epoch: 2824, Loss: 0.0678, Train: 0.2601, Val: 0.2875
# Epoch: 2825, Loss: 0.0677, Train: 0.2602, Val: 0.2849
# Epoch: 2826, Loss: 0.0677, Train: 0.2599, Val: 0.2873
# Epoch: 2827, Loss: 0.0676, Train: 0.2599, Val: 0.2850
# Epoch: 2828, Loss: 0.0676, Train: 0.2595, Val: 0.2867
# Epoch: 2829, Loss: 0.0675, Train: 0.2595, Val: 0.2852
# Epoch: 2830, Loss: 0.0674, Train: 0.2593, Val: 0.2860
# Epoch: 2831, Loss: 0.0673, Train: 0.2593, Val: 0.2856
# Epoch: 2832, Loss: 0.0673, Train: 0.2593, Val: 0.2854
# Epoch: 2833, Loss: 0.0673, Train: 0.2593, Val: 0.2860
# Epoch: 2834, Loss: 0.0673, Train: 0.2595, Val: 0.2851
# Epoch: 2835, Loss: 0.0674, Train: 0.2595, Val: 0.2865
# Epoch: 2836, Loss: 0.0674, Train: 0.2597, Val: 0.2850
# Epoch: 2837, Loss: 0.0675, Train: 0.2597, Val: 0.2871
# Epoch: 2838, Loss: 0.0675, Train: 0.2600, Val: 0.2850
# Epoch: 2839, Loss: 0.0676, Train: 0.2600, Val: 0.2877
# Epoch: 2840, Loss: 0.0677, Train: 0.2603, Val: 0.2851
# Epoch: 2841, Loss: 0.0678, Train: 0.2601, Val: 0.2881
# Epoch: 2842, Loss: 0.0678, Train: 0.2603, Val: 0.2853
# Epoch: 2843, Loss: 0.0678, Train: 0.2600, Val: 0.2879
# Epoch: 2844, Loss: 0.0677, Train: 0.2600, Val: 0.2853
# Epoch: 2845, Loss: 0.0676, Train: 0.2596, Val: 0.2873
# Epoch: 2846, Loss: 0.0675, Train: 0.2595, Val: 0.2855
# Epoch: 2847, Loss: 0.0674, Train: 0.2593, Val: 0.2864
# Epoch: 2848, Loss: 0.0673, Train: 0.2593, Val: 0.2859
# Epoch: 2849, Loss: 0.0673, Train: 0.2593, Val: 0.2857
# Epoch: 2850, Loss: 0.0673, Train: 0.2593, Val: 0.2864
# Epoch: 2851, Loss: 0.0673, Train: 0.2595, Val: 0.2854
# Epoch: 2852, Loss: 0.0674, Train: 0.2596, Val: 0.2870
# Epoch: 2853, Loss: 0.0675, Train: 0.2598, Val: 0.2853
# Epoch: 2854, Loss: 0.0675, Train: 0.2598, Val: 0.2877
# Epoch: 2855, Loss: 0.0676, Train: 0.2602, Val: 0.2854
# Epoch: 2856, Loss: 0.0677, Train: 0.2601, Val: 0.2882
# Epoch: 2857, Loss: 0.0678, Train: 0.2603, Val: 0.2855
# Epoch: 2858, Loss: 0.0678, Train: 0.2601, Val: 0.2884
# Epoch: 2859, Loss: 0.0677, Train: 0.2601, Val: 0.2856
# Epoch: 2860, Loss: 0.0677, Train: 0.2597, Val: 0.2878
# Epoch: 2861, Loss: 0.0676, Train: 0.2596, Val: 0.2858
# Epoch: 2862, Loss: 0.0674, Train: 0.2593, Val: 0.2869
# Epoch: 2863, Loss: 0.0673, Train: 0.2593, Val: 0.2861
# Epoch: 2864, Loss: 0.0673, Train: 0.2593, Val: 0.2861
# Epoch: 2865, Loss: 0.0673, Train: 0.2593, Val: 0.2866
# Epoch: 2866, Loss: 0.0673, Train: 0.2594, Val: 0.2857
# Epoch: 2867, Loss: 0.0674, Train: 0.2595, Val: 0.2872
# Epoch: 2868, Loss: 0.0674, Train: 0.2598, Val: 0.2856
# Epoch: 2869, Loss: 0.0675, Train: 0.2598, Val: 0.2879
# Epoch: 2870, Loss: 0.0676, Train: 0.2602, Val: 0.2856
# Epoch: 2871, Loss: 0.0677, Train: 0.2601, Val: 0.2885
# Epoch: 2872, Loss: 0.0678, Train: 0.2604, Val: 0.2857
# Epoch: 2873, Loss: 0.0678, Train: 0.2601, Val: 0.2887
# Epoch: 2874, Loss: 0.0678, Train: 0.2602, Val: 0.2859
# Epoch: 2875, Loss: 0.0677, Train: 0.2598, Val: 0.2882
# Epoch: 2876, Loss: 0.0676, Train: 0.2596, Val: 0.2860
# Epoch: 2877, Loss: 0.0674, Train: 0.2593, Val: 0.2872
# Epoch: 2878, Loss: 0.0673, Train: 0.2592, Val: 0.2864
# Epoch: 2879, Loss: 0.0673, Train: 0.2593, Val: 0.2864
# Epoch: 2880, Loss: 0.0673, Train: 0.2593, Val: 0.2870
# Epoch: 2881, Loss: 0.0673, Train: 0.2595, Val: 0.2859
# Epoch: 2882, Loss: 0.0674, Train: 0.2596, Val: 0.2877
# Epoch: 2883, Loss: 0.0675, Train: 0.2599, Val: 0.2858
# Epoch: 2884, Loss: 0.0676, Train: 0.2599, Val: 0.2883
# Epoch: 2885, Loss: 0.0676, Train: 0.2602, Val: 0.2858
# Epoch: 2886, Loss: 0.0678, Train: 0.2601, Val: 0.2888
# Epoch: 2887, Loss: 0.0678, Train: 0.2603, Val: 0.2860
# Epoch: 2888, Loss: 0.0678, Train: 0.2599, Val: 0.2887
# Epoch: 2889, Loss: 0.0677, Train: 0.2599, Val: 0.2861
# Epoch: 2890, Loss: 0.0676, Train: 0.2595, Val: 0.2879
# Epoch: 2891, Loss: 0.0674, Train: 0.2594, Val: 0.2864
# Epoch: 2892, Loss: 0.0673, Train: 0.2592, Val: 0.2870
# Epoch: 2893, Loss: 0.0673, Train: 0.2592, Val: 0.2869
# Epoch: 2894, Loss: 0.0673, Train: 0.2593, Val: 0.2863
# Epoch: 2895, Loss: 0.0673, Train: 0.2594, Val: 0.2876
# Epoch: 2896, Loss: 0.0674, Train: 0.2597, Val: 0.2860
# Epoch: 2897, Loss: 0.0675, Train: 0.2597, Val: 0.2882
# Epoch: 2898, Loss: 0.0675, Train: 0.2600, Val: 0.2860
# Epoch: 2899, Loss: 0.0676, Train: 0.2600, Val: 0.2887
# Epoch: 2900, Loss: 0.0677, Train: 0.2602, Val: 0.2861
# Epoch: 2901, Loss: 0.0677, Train: 0.2600, Val: 0.2889
# Epoch: 2902, Loss: 0.0677, Train: 0.2600, Val: 0.2863
# Epoch: 2903, Loss: 0.0677, Train: 0.2597, Val: 0.2885
# Epoch: 2904, Loss: 0.0675, Train: 0.2596, Val: 0.2865
# Epoch: 2905, Loss: 0.0674, Train: 0.2593, Val: 0.2877
# Epoch: 2906, Loss: 0.0673, Train: 0.2592, Val: 0.2868
# Epoch: 2907, Loss: 0.0673, Train: 0.2592, Val: 0.2869
# Epoch: 2908, Loss: 0.0673, Train: 0.2592, Val: 0.2874
# Epoch: 2909, Loss: 0.0673, Train: 0.2594, Val: 0.2865
# Epoch: 2910, Loss: 0.0673, Train: 0.2594, Val: 0.2879
# Epoch: 2911, Loss: 0.0674, Train: 0.2596, Val: 0.2863
# Epoch: 2912, Loss: 0.0675, Train: 0.2597, Val: 0.2884
# Epoch: 2913, Loss: 0.0675, Train: 0.2599, Val: 0.2863
# Epoch: 2914, Loss: 0.0676, Train: 0.2598, Val: 0.2889
# Epoch: 2915, Loss: 0.0676, Train: 0.2600, Val: 0.2864
# Epoch: 2916, Loss: 0.0677, Train: 0.2598, Val: 0.2890
# Epoch: 2917, Loss: 0.0676, Train: 0.2599, Val: 0.2865
# Epoch: 2918, Loss: 0.0676, Train: 0.2596, Val: 0.2887
# Epoch: 2919, Loss: 0.0675, Train: 0.2596, Val: 0.2867
# Epoch: 2920, Loss: 0.0674, Train: 0.2593, Val: 0.2880
# Epoch: 2921, Loss: 0.0673, Train: 0.2593, Val: 0.2870
# Epoch: 2922, Loss: 0.0673, Train: 0.2592, Val: 0.2873
# Epoch: 2923, Loss: 0.0672, Train: 0.2592, Val: 0.2874
# Epoch: 2924, Loss: 0.0672, Train: 0.2593, Val: 0.2869
# Epoch: 2925, Loss: 0.0673, Train: 0.2593, Val: 0.2878
# Epoch: 2926, Loss: 0.0673, Train: 0.2594, Val: 0.2866
# Epoch: 2927, Loss: 0.0674, Train: 0.2595, Val: 0.2883
# Epoch: 2928, Loss: 0.0674, Train: 0.2597, Val: 0.2866
# Epoch: 2929, Loss: 0.0675, Train: 0.2597, Val: 0.2888
# Epoch: 2930, Loss: 0.0675, Train: 0.2599, Val: 0.2866
# Epoch: 2931, Loss: 0.0676, Train: 0.2598, Val: 0.2892
# Epoch: 2932, Loss: 0.0676, Train: 0.2600, Val: 0.2867
# Epoch: 2933, Loss: 0.0677, Train: 0.2598, Val: 0.2892
# Epoch: 2934, Loss: 0.0676, Train: 0.2599, Val: 0.2867
# Epoch: 2935, Loss: 0.0676, Train: 0.2596, Val: 0.2889
# Epoch: 2936, Loss: 0.0675, Train: 0.2595, Val: 0.2869
# Epoch: 2937, Loss: 0.0674, Train: 0.2593, Val: 0.2882
# Epoch: 2938, Loss: 0.0673, Train: 0.2592, Val: 0.2871
# Epoch: 2939, Loss: 0.0673, Train: 0.2592, Val: 0.2875
# Epoch: 2940, Loss: 0.0672, Train: 0.2592, Val: 0.2875
# Epoch: 2941, Loss: 0.0672, Train: 0.2592, Val: 0.2871
# Epoch: 2942, Loss: 0.0672, Train: 0.2592, Val: 0.2879
# Epoch: 2943, Loss: 0.0673, Train: 0.2594, Val: 0.2869
# Epoch: 2944, Loss: 0.0673, Train: 0.2594, Val: 0.2884
# Epoch: 2945, Loss: 0.0674, Train: 0.2596, Val: 0.2868
# Epoch: 2946, Loss: 0.0674, Train: 0.2597, Val: 0.2889
# Epoch: 2947, Loss: 0.0675, Train: 0.2599, Val: 0.2868
# Epoch: 2948, Loss: 0.0676, Train: 0.2599, Val: 0.2895
# Epoch: 2949, Loss: 0.0676, Train: 0.2602, Val: 0.2869
# Epoch: 2950, Loss: 0.0677, Train: 0.2600, Val: 0.2897
# Epoch: 2951, Loss: 0.0677, Train: 0.2601, Val: 0.2869
# Epoch: 2952, Loss: 0.0677, Train: 0.2597, Val: 0.2893
# Epoch: 2953, Loss: 0.0675, Train: 0.2596, Val: 0.2870
# Epoch: 2954, Loss: 0.0675, Train: 0.2594, Val: 0.2886
# Epoch: 2955, Loss: 0.0673, Train: 0.2593, Val: 0.2873
# Epoch: 2956, Loss: 0.0673, Train: 0.2592, Val: 0.2878
# Epoch: 2957, Loss: 0.0672, Train: 0.2592, Val: 0.2876
# Epoch: 2958, Loss: 0.0672, Train: 0.2592, Val: 0.2873
# Epoch: 2959, Loss: 0.0672, Train: 0.2592, Val: 0.2881
# Epoch: 2960, Loss: 0.0673, Train: 0.2594, Val: 0.2871
# Epoch: 2961, Loss: 0.0673, Train: 0.2594, Val: 0.2886
# Epoch: 2962, Loss: 0.0674, Train: 0.2596, Val: 0.2870
# Epoch: 2963, Loss: 0.0674, Train: 0.2597, Val: 0.2892
# Epoch: 2964, Loss: 0.0675, Train: 0.2599, Val: 0.2870
# Epoch: 2965, Loss: 0.0676, Train: 0.2599, Val: 0.2897
# Epoch: 2966, Loss: 0.0676, Train: 0.2602, Val: 0.2871
# Epoch: 2967, Loss: 0.0677, Train: 0.2600, Val: 0.2899
# Epoch: 2968, Loss: 0.0677, Train: 0.2601, Val: 0.2872
# Epoch: 2969, Loss: 0.0677, Train: 0.2597, Val: 0.2895
# Epoch: 2970, Loss: 0.0675, Train: 0.2596, Val: 0.2872
# Epoch: 2971, Loss: 0.0674, Train: 0.2593, Val: 0.2888
# Epoch: 2972, Loss: 0.0673, Train: 0.2593, Val: 0.2875
# Epoch: 2973, Loss: 0.0673, Train: 0.2592, Val: 0.2880
# Epoch: 2974, Loss: 0.0672, Train: 0.2591, Val: 0.2878
# Epoch: 2975, Loss: 0.0672, Train: 0.2592, Val: 0.2876
# Epoch: 2976, Loss: 0.0672, Train: 0.2592, Val: 0.2882
# Epoch: 2977, Loss: 0.0673, Train: 0.2593, Val: 0.2873
# Epoch: 2978, Loss: 0.0673, Train: 0.2594, Val: 0.2887
# Epoch: 2979, Loss: 0.0673, Train: 0.2596, Val: 0.2872
# Epoch: 2980, Loss: 0.0674, Train: 0.2596, Val: 0.2893
# Epoch: 2981, Loss: 0.0675, Train: 0.2599, Val: 0.2872
# Epoch: 2982, Loss: 0.0676, Train: 0.2599, Val: 0.2899
# Epoch: 2983, Loss: 0.0676, Train: 0.2601, Val: 0.2873
# Epoch: 2984, Loss: 0.0677, Train: 0.2599, Val: 0.2900
# Epoch: 2985, Loss: 0.0677, Train: 0.2600, Val: 0.2873
# Epoch: 2986, Loss: 0.0676, Train: 0.2597, Val: 0.2897
# Epoch: 2987, Loss: 0.0675, Train: 0.2596, Val: 0.2874
# Epoch: 2988, Loss: 0.0674, Train: 0.2594, Val: 0.2890
# Epoch: 2989, Loss: 0.0673, Train: 0.2593, Val: 0.2876
# Epoch: 2990, Loss: 0.0673, Train: 0.2591, Val: 0.2883
# Epoch: 2991, Loss: 0.0672, Train: 0.2591, Val: 0.2879
# Epoch: 2992, Loss: 0.0672, Train: 0.2591, Val: 0.2878
# Epoch: 2993, Loss: 0.0672, Train: 0.2592, Val: 0.2883
# Epoch: 2994, Loss: 0.0672, Train: 0.2593, Val: 0.2875
# Epoch: 2995, Loss: 0.0673, Train: 0.2593, Val: 0.2887
# Epoch: 2996, Loss: 0.0673, Train: 0.2595, Val: 0.2874
# Epoch: 2997, Loss: 0.0674, Train: 0.2595, Val: 0.2892
# Epoch: 2998, Loss: 0.0674, Train: 0.2597, Val: 0.2873
# Epoch: 2999, Loss: 0.0675, Train: 0.2597, Val: 0.2897
# Epoch: 3000, Loss: 0.0675, Train: 0.2600, Val: 0.2874

# %%
@torch.no_grad()
def predict(data, edge_label_index=None):
    """
    Generate predicted ratings for the given user→business edges.

    Args:
        data: HeteroData (must have x_dict & edge_index_dict).
        edge_label_index: Tensor[2, num_edges] of (user,business) pairs.
                          If None, uses data['user','rates','business'].edge_label_index.

    Returns:
        Tensor of shape [num_edges] with ratings in [0,5], on CPU.
    """
    model.eval()
    data = data.to(device)
    if edge_label_index is None:
        edge_label_index = data['user','rates','business'].edge_label_index
    pred = model(data.x_dict, data.edge_index_dict, edge_label_index)
    pred = pred.clamp(min=0, max=5)
    return pred.cpu()

# %%
import numpy as np
import pandas as pd

# Haversine distance (returns km)
def haversine(lon1, lat1, lon2, lat2):
    R = 6371.0  # Earth radius in km
    φ1 = np.radians(lat1)
    φ2 = np.radians(lat2)
    Δφ = np.radians(lat2 - lat1)
    Δλ = np.radians(lon2 - lon1)
    a = np.sin(Δφ / 2.0)**2 + np.cos(φ1) * np.cos(φ2) * np.sin(Δλ / 2.0)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    return R * c

def recommend(lat, lng, radius, hour=None, top_k=20):
    """
    Return the top_k businesses within `radius` km of (lat, lng), 
    sorted by average stars descending.

    Args:
        lat (float): latitude of the query point
        lng (float): longitude of the query point
        radius (float): radius in kilometers
        hour (int, optional): hour of day (unused in this simple version)
        top_k (int): how many results to return
    Returns:
        pandas.DataFrame of top_k businesses with distance column
    """
    # Load preprocessed businesses (if not already loaded)
    try:
        df = business_df.copy()
    except NameError:
        df = pd.read_parquet('../../Data/preprocessed_business.parquet', engine='pyarrow')
    
    # Compute distance
    df['distance_km'] = haversine(
        lng, lat,
        df['longitude'].values,
        df['latitude'].values
    )
    # Filter and sort
    df = df[df['distance_km'] <= radius]
    df = df.sort_values(['stars', 'distance_km'], ascending=[False, True])
    
    return df.head(top_k)

# Example usage:
top20 = recommend(37.77, -122.42, radius=5)
print(top20[['name','stars','review_count','distance_km']])
# Out:
# Empty DataFrame
# Columns: [name, stars, review_count, distance_km]
# Index: []

# %% [markdown]
# TESTING:
#
#  - root MSE
#  - k order ranking
#     - List of edges in test dataset
#     - Compare to see if the order is correct:
#         - how many are in the top 5
#         - how many are in the correct order
#
# - Screen shots
#     - GUI
#     - Results
#     -
#
# - Looking at different models
#     - optiums
#     - looking at
